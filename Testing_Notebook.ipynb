# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import librosa
import librosa.display
import sklearn as sk

# %matplotlib inline

# %% [markdown]
# ## MFCC Extraction

# %%
audio_file_name = '03-01-01-01-01-01-01.wav'

y, sr = librosa.load(audio_file_name, sr=44100)
mfcc = librosa.feature.mfcc(y=y, sr=sr)

mfcc.shape
# Out:
# (20, 285)

# %% [markdown]
# # Spectral Centroids

# %%
spec_cent = librosa.feature.spectral_centroid(y+0.01, sr=sr)[0]
frames = range(len(spec_cent))
t = librosa.frames_to_time(frames)

def normalize(x, axis=0):
    return sk.preprocessing.minmax_scale(x, axis=axis)

# https://musicinformationretrieval.com/spectral_features.html

# %% [markdown]
# ## Waveform Plot

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveplot(y, sr=sr)
# plot normalized centroid
plt.plot(t, normalize(spec_cent), color='r')

# %% [markdown]
# ## Spectrogram Plot

# %%
#display Spectrogram
X = librosa.stft(y)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz') 
#If to pring log of frequencies  
#librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()

# %% [markdown]
# # Process Data In A Loop

# %%
audio_file_name = '03-01-01-01-01-01-01.wav'

y, sr = librosa.load(audio_file_name, sr=44100)
mfcc = librosa.feature.mfcc(y=y, sr=sr)

mfcc.shape
# Out:
# (20, 285)

# %%
# 23 * 60 * 20 * len_audio_clip
voice_data_dir = "voice_data"
dir_actors = os.listdir(voice_data_dir)
num_wav = 60
num_mfcc_x = mfcc[0].size
num_mfcc_y = len(mfcc)
x = np.array([])

# %%
# Itarate through actor directories and then wav files
for i in range(len(dir_actors)):
    wavs = os.listdir(voice_data_dir + "/" + dir_actors[i])
    for j in range(len(wavs)):
        wav_dir = voice_data_dir + "/" + dir_actors[i] + "/" + wavs[j]
        # Process data here
        # Must manage variable length sequences for data processing



        # y, sr = librosa.load(wav_dir, sr=44100)
        # mfcc = librosa.feature.mfcc(y=y, sr=sr)
        # if (mfcc[0].size > longest_mfcc):
        #     longest_mfcc = mfcc[0].size
        # x = np.append(x, mfcc)
