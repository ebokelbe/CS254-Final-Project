# %% [markdown]
# # Convolutional Neural Network Using Mel Spectrogram Classifying Gender

# %%
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Flatten, Conv2D, MaxPooling2D, LeakyReLU
from keras.optimizers import SGD
from keras.utils import to_categorical
from keras.regularizers import l2
from sklearn.preprocessing import MinMaxScaler
import librosa
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
audio_data = np.load("../data/audio_data.npy")
labels = np.load("../data/wav_labels.npy")

# labels: modality-vocal channel-emotion-emotional intensity-statement-repetition-actor
# emotions: 01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised
# odd number actors = male, even = female

# 1440 files: 24 speakers, 60 recordings per speaker
audio_data = audio_data.reshape(1440, 9480)

features = []

for i in range(1440):
    
    if (labels[i][6]%2 == 0):
        label = "Female"
    else:
        label = "Male"

    if (labels[i][2] == 1):
        em = 0
    elif (labels[i][2] == 2):
        em = 1
    elif (labels[i][2] == 3):
        em = 2
    elif (labels[i][2] == 4):
        em = 3
    elif (labels[i][2] == 5):
        em = 4
    elif (labels[i][2] == 6):
        em = 5
    elif (labels[i][2] == 7):
        em = 6
    elif (labels[i][2] == 8):
        em = 7
    
    features.append([audio_data[i], label, em])
    
feature_df = pd.DataFrame(features, columns = ["mfcc", "gender", "emotion"])

feature_df.head()
# Out:
#                                                 mfcc  gender  emotion
# 0  [-710.0553588867188, -709.9026489257812, -711....  Female        0
# 1  [-547.765625, -548.0353393554688, -548.6129760...  Female        2
# 2  [-616.4595336914062, -615.7564697265625, -615....  Female        7
# 3  [-739.8626098632812, -738.7739868164062, -735....  Female        1
# 4  [-698.0630493164062, -697.3838500976562, -696....  Female        4

# %%
#split data - males vs females
mal = feature_df.loc[feature_df['gender'] == "Male"]
fem = feature_df.loc[feature_df['gender'] == "Female"]

## ===== Females ===== ##
X_females_unscaled = np.array(fem.mfcc.tolist())
y_females = np.array(fem.emotion.tolist())

scaler = MinMaxScaler(feature_range=(-1,1))
scaler.fit(X_females_unscaled)
X_females_scaled = scaler.transform(X_females_unscaled)

#20-80 train-test split
X_train_females, X_test_females, y_train_females, y_test_females = train_test_split(X_females_scaled, y_females, test_size=0.20, random_state=0)

# %%
# Reshape for CNN input
X_train_females = np.array([x.reshape( (20, 474, 1) ) for x in X_train_females])
X_test_females = np.array([x.reshape( (20, 474, 1) ) for x in X_test_females])

# One-Hot encoding for classes
y_train_females = np.array(to_categorical(y_train_females, 8))
y_test_females = np.array(to_categorical(y_test_females, 8))

# %%
model = Sequential()

model.add(Conv2D(64, (5,5), input_shape=X_test_females.shape[1:], kernel_regularizer=l2(l=0.01)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(24, (4,4)))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(rate=0.2))

model.add(Conv2D(24, (3,3)))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(rate=0.2))

model.add(Conv2D(80, (2,2)))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(rate=0.5))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))

model.add(Dense(8))
model.add(Activation('softmax'))

# %%
model.compile(
	optimizer="Adam",
	loss="categorical_crossentropy",
	metrics=['accuracy']
)

model.fit(
	x=X_train_females,
	y=y_train_females,
    epochs=100,
    batch_size=64,
    validation_data= (X_test_females, y_test_females)
)

score = model.evaluate(
	x=X_test_females,
	y=y_test_females)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/100
# 1/9 [==>...........................] - ETA: 0s - loss: 2.1005 - accuracy: 0.1094WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0023s vs `on_train_batch_end` time: 0.0194s). Check your callbacks.
# 9/9 [==============================] - 0s 44ms/step - loss: 2.1012 - accuracy: 0.1163 - val_loss: 2.0683 - val_accuracy: 0.1250
# Epoch 2/100
# 9/9 [==============================] - 0s 25ms/step - loss: 2.0530 - accuracy: 0.1840 - val_loss: 1.9868 - val_accuracy: 0.3056
# Epoch 3/100
# 9/9 [==============================] - 0s 25ms/step - loss: 1.8912 - accuracy: 0.3003 - val_loss: 1.7392 - val_accuracy: 0.3264
# Epoch 4/100
# 9/9 [==============================] - 0s 25ms/step - loss: 1.6173 - accuracy: 0.4045 - val_loss: 1.4863 - val_accuracy: 0.4514
# Epoch 5/100
# 9/9 [==============================] - 0s 25ms/step - loss: 1.3214 - accuracy: 0.5035 - val_loss: 1.2276 - val_accuracy: 0.5486
# Epoch 6/100
# 9/9 [==============================] - 0s 25ms/step - loss: 1.0574 - accuracy: 0.6319 - val_loss: 1.1940 - val_accuracy: 0.5486
# Epoch 7/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.9287 - accuracy: 0.6545 - val_loss: 1.1876 - val_accuracy: 0.5833
# Epoch 8/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.8054 - accuracy: 0.7240 - val_loss: 1.0787 - val_accuracy: 0.6181
# Epoch 9/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.5993 - accuracy: 0.8003 - val_loss: 0.9927 - val_accuracy: 0.6806
# Epoch 10/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4585 - accuracy: 0.8420 - val_loss: 1.0324 - val_accuracy: 0.6667
# Epoch 11/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.3870 - accuracy: 0.8802 - val_loss: 1.1095 - val_accuracy: 0.6806
# Epoch 12/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.2986 - accuracy: 0.9062 - val_loss: 1.1988 - val_accuracy: 0.6528
# Epoch 13/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.2547 - accuracy: 0.9184 - val_loss: 1.0039 - val_accuracy: 0.7153
# Epoch 14/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.2136 - accuracy: 0.9392 - val_loss: 1.1551 - val_accuracy: 0.7083
# Epoch 15/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.2281 - accuracy: 0.9201 - val_loss: 1.2295 - val_accuracy: 0.6597
# Epoch 16/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.2048 - accuracy: 0.9323 - val_loss: 1.1878 - val_accuracy: 0.6806
# Epoch 17/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.2067 - accuracy: 0.9253 - val_loss: 1.3084 - val_accuracy: 0.6736
# Epoch 18/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.1470 - accuracy: 0.9497 - val_loss: 1.3671 - val_accuracy: 0.6944
# Epoch 19/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.1082 - accuracy: 0.9774 - val_loss: 1.3183 - val_accuracy: 0.7014
# Epoch 20/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0775 - accuracy: 0.9878 - val_loss: 1.3183 - val_accuracy: 0.7292
# Epoch 21/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0893 - accuracy: 0.9774 - val_loss: 1.3320 - val_accuracy: 0.7431
# Epoch 22/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0625 - accuracy: 0.9861 - val_loss: 1.1982 - val_accuracy: 0.7361
# Epoch 23/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0567 - accuracy: 0.9896 - val_loss: 1.3863 - val_accuracy: 0.7153
# Epoch 24/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0840 - accuracy: 0.9792 - val_loss: 1.4179 - val_accuracy: 0.7014
# Epoch 25/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0743 - accuracy: 0.9896 - val_loss: 1.4352 - val_accuracy: 0.7083
# Epoch 26/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0984 - accuracy: 0.9740 - val_loss: 1.5432 - val_accuracy: 0.7222
# Epoch 27/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.1098 - accuracy: 0.9740 - val_loss: 1.4299 - val_accuracy: 0.7222
# Epoch 28/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0687 - accuracy: 0.9861 - val_loss: 1.4642 - val_accuracy: 0.7222
# Epoch 29/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0779 - accuracy: 0.9774 - val_loss: 1.6267 - val_accuracy: 0.7014
# Epoch 30/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0644 - accuracy: 0.9826 - val_loss: 1.7565 - val_accuracy: 0.6944
# Epoch 31/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0801 - accuracy: 0.9913 - val_loss: 1.7942 - val_accuracy: 0.6944
# Epoch 32/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0597 - accuracy: 0.9913 - val_loss: 1.7878 - val_accuracy: 0.7222
# Epoch 33/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0550 - accuracy: 0.9913 - val_loss: 1.5389 - val_accuracy: 0.7083
# Epoch 34/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0732 - accuracy: 0.9826 - val_loss: 2.0349 - val_accuracy: 0.6250
# Epoch 35/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0650 - accuracy: 0.9844 - val_loss: 1.7374 - val_accuracy: 0.7222
# Epoch 36/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0724 - accuracy: 0.9809 - val_loss: 2.0537 - val_accuracy: 0.6875
# Epoch 37/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0550 - accuracy: 0.9931 - val_loss: 1.8269 - val_accuracy: 0.7292
# Epoch 38/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0458 - accuracy: 0.9948 - val_loss: 1.8673 - val_accuracy: 0.7361
# Epoch 39/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0582 - accuracy: 0.9878 - val_loss: 2.0553 - val_accuracy: 0.6944
# Epoch 40/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0338 - accuracy: 0.9983 - val_loss: 1.7684 - val_accuracy: 0.6944
# Epoch 41/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0433 - accuracy: 0.9965 - val_loss: 1.6388 - val_accuracy: 0.7292
# Epoch 42/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0370 - accuracy: 0.9965 - val_loss: 1.8131 - val_accuracy: 0.7083
# Epoch 43/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0425 - accuracy: 0.9913 - val_loss: 1.9331 - val_accuracy: 0.7014
# Epoch 44/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0365 - accuracy: 0.9983 - val_loss: 1.5333 - val_accuracy: 0.7431
# Epoch 45/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0513 - accuracy: 0.9913 - val_loss: 1.8256 - val_accuracy: 0.7153
# Epoch 46/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0383 - accuracy: 0.9948 - val_loss: 1.5954 - val_accuracy: 0.7431
# Epoch 47/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0294 - accuracy: 0.9983 - val_loss: 1.7949 - val_accuracy: 0.7083
# Epoch 48/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0273 - accuracy: 1.0000 - val_loss: 1.7722 - val_accuracy: 0.7222
# Epoch 49/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0343 - accuracy: 0.9948 - val_loss: 1.7526 - val_accuracy: 0.7222
# Epoch 50/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0483 - accuracy: 0.9913 - val_loss: 1.8259 - val_accuracy: 0.6875
# Epoch 51/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0532 - accuracy: 0.9931 - val_loss: 1.7506 - val_accuracy: 0.6944
# Epoch 52/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0358 - accuracy: 0.9948 - val_loss: 1.7807 - val_accuracy: 0.7153
# Epoch 53/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0381 - accuracy: 0.9948 - val_loss: 1.6166 - val_accuracy: 0.7569
# Epoch 54/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0361 - accuracy: 0.9948 - val_loss: 1.8273 - val_accuracy: 0.7014
# Epoch 55/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0490 - accuracy: 0.9878 - val_loss: 1.6972 - val_accuracy: 0.7014
# Epoch 56/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0452 - accuracy: 0.9931 - val_loss: 1.6548 - val_accuracy: 0.7083
# Epoch 57/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0392 - accuracy: 0.9948 - val_loss: 1.4595 - val_accuracy: 0.7569
# Epoch 58/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0264 - accuracy: 0.9983 - val_loss: 1.5852 - val_accuracy: 0.7153
# Epoch 59/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0327 - accuracy: 0.9931 - val_loss: 1.6372 - val_accuracy: 0.7292
# Epoch 60/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0257 - accuracy: 0.9983 - val_loss: 1.6730 - val_accuracy: 0.7361
# Epoch 61/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0395 - accuracy: 0.9931 - val_loss: 2.1792 - val_accuracy: 0.6806
# Epoch 62/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0560 - accuracy: 0.9913 - val_loss: 1.9448 - val_accuracy: 0.7431
# Epoch 63/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0633 - accuracy: 0.9861 - val_loss: 2.4015 - val_accuracy: 0.6944
# Epoch 64/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0553 - accuracy: 0.9913 - val_loss: 2.6741 - val_accuracy: 0.6806
# Epoch 65/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0390 - accuracy: 0.9931 - val_loss: 2.0534 - val_accuracy: 0.7083
# Epoch 66/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0486 - accuracy: 0.9878 - val_loss: 1.9037 - val_accuracy: 0.7500
# Epoch 67/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0441 - accuracy: 0.9844 - val_loss: 1.9144 - val_accuracy: 0.7222
# Epoch 68/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0480 - accuracy: 0.9878 - val_loss: 1.8891 - val_accuracy: 0.7222
# Epoch 69/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0674 - accuracy: 0.9809 - val_loss: 1.8340 - val_accuracy: 0.6806
# Epoch 70/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0478 - accuracy: 0.9931 - val_loss: 1.6713 - val_accuracy: 0.7639
# Epoch 71/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0280 - accuracy: 0.9965 - val_loss: 1.9276 - val_accuracy: 0.7431
# Epoch 72/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0332 - accuracy: 0.9948 - val_loss: 2.1082 - val_accuracy: 0.7153
# Epoch 73/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0352 - accuracy: 0.9965 - val_loss: 2.0495 - val_accuracy: 0.7292
# Epoch 74/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0299 - accuracy: 0.9948 - val_loss: 1.9888 - val_accuracy: 0.7153
# Epoch 75/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0249 - accuracy: 0.9965 - val_loss: 1.9675 - val_accuracy: 0.7153
# Epoch 76/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0286 - accuracy: 0.9965 - val_loss: 1.7666 - val_accuracy: 0.7292
# Epoch 77/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0248 - accuracy: 0.9948 - val_loss: 1.8923 - val_accuracy: 0.7222
# Epoch 78/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0236 - accuracy: 0.9983 - val_loss: 1.9314 - val_accuracy: 0.7431
# Epoch 79/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0328 - accuracy: 0.9965 - val_loss: 1.9952 - val_accuracy: 0.7222
# Epoch 80/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0330 - accuracy: 0.9948 - val_loss: 2.0338 - val_accuracy: 0.7361
# Epoch 81/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0285 - accuracy: 0.9965 - val_loss: 2.0220 - val_accuracy: 0.7292
# Epoch 82/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0251 - accuracy: 0.9965 - val_loss: 1.8180 - val_accuracy: 0.7431
# Epoch 83/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 1.7630 - val_accuracy: 0.7292
# Epoch 84/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0221 - accuracy: 0.9965 - val_loss: 2.0088 - val_accuracy: 0.7292
# Epoch 85/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0252 - accuracy: 0.9965 - val_loss: 1.7590 - val_accuracy: 0.7431
# Epoch 86/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0190 - accuracy: 1.0000 - val_loss: 1.9086 - val_accuracy: 0.7292
# Epoch 87/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 2.1139 - val_accuracy: 0.7083
# Epoch 88/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 2.1934 - val_accuracy: 0.7014
# Epoch 89/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 2.0523 - val_accuracy: 0.7292
# Epoch 90/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 2.0317 - val_accuracy: 0.7222
# Epoch 91/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 1.9798 - val_accuracy: 0.7292
# Epoch 92/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 2.0223 - val_accuracy: 0.7361
# Epoch 93/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 2.1490 - val_accuracy: 0.7292
# Epoch 94/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 2.0224 - val_accuracy: 0.7292
# Epoch 95/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 2.0403 - val_accuracy: 0.7222
# Epoch 96/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 2.1534 - val_accuracy: 0.7292
# Epoch 97/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 2.1304 - val_accuracy: 0.7292
# Epoch 98/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 2.1265 - val_accuracy: 0.7153
# Epoch 99/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 2.1099 - val_accuracy: 0.7083
# Epoch 100/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 2.0977 - val_accuracy: 0.7153
# 5/5 [==============================] - 0s 4ms/step - loss: 2.0977 - accuracy: 0.7153
# Test loss: 2.0977468490600586
# Test accuracy: 0.7152777910232544
