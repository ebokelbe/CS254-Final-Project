# %% [markdown]
# # Convolutional Neural Network Using Mel Spectrogram Classifying Gender

# %%
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Flatten, Conv2D, MaxPooling2D, LeakyReLU
from keras.optimizers import SGD
from keras.utils import to_categorical
from keras.regularizers import l2
from sklearn.preprocessing import MinMaxScaler
import librosa
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
audio_data = np.load("../data/audio_data.npy")
labels = np.load("../data/wav_labels.npy")

# labels: modality-vocal channel-emotion-emotional intensity-statement-repetition-actor
# emotions: 01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised
# odd number actors = male, even = female

# 1440 files: 24 speakers, 60 recordings per speaker
audio_data = audio_data.reshape(1440, 9480)

features = []

for i in range(1440):
    
    if (labels[i][6]%2 == 0):
        label = "Female"
    else:
        label = "Male"

    if (labels[i][2] == 1):
        em = 0
    elif (labels[i][2] == 2):
        em = 1
    elif (labels[i][2] == 3):
        em = 2
    elif (labels[i][2] == 4):
        em = 3
    elif (labels[i][2] == 5):
        em = 4
    elif (labels[i][2] == 6):
        em = 5
    elif (labels[i][2] == 7):
        em = 6
    elif (labels[i][2] == 8):
        em = 7
    
    features.append([audio_data[i], label, em])
    
feature_df = pd.DataFrame(features, columns = ["mfcc", "gender", "emotion"])

feature_df.head()
# Out:
#                                                 mfcc gender  emotion
# 0  [-855.3770751953125, -855.3770751953125, -855....   Male        0
# 1  [-850.3917236328125, -850.435791015625, -850.4...   Male        0
# 2  [-849.78369140625, -848.8447265625, -848.56610...   Male        0
# 3  [-842.9385375976562, -843.2474975585938, -850....   Male        0
# 4  [-911.1758422851562, -910.4053344726562, -905....   Male        1

# %%
#split data - males vs females
mal = feature_df.loc[feature_df['gender'] == "Male"]
fem = feature_df.loc[feature_df['gender'] == "Female"]

## ===== Females ===== ##
X_females_unscaled = np.array(fem.mfcc.tolist())
y_females = np.array(fem.emotion.tolist())

scaler = MinMaxScaler(feature_range=(-1,1))
scaler.fit(X_females_unscaled)
X_females_scaled = scaler.transform(X_females_unscaled)

#20-80 train-test split
X_train_females, X_test_females, y_train_females, y_test_females = train_test_split(X_females_scaled, y_females, test_size=0.20, random_state=0)

# %%
# Reshape for CNN input
X_train_females = np.array([x.reshape( (20, 474, 1) ) for x in X_train_females])
X_test_females = np.array([x.reshape( (20, 474, 1) ) for x in X_test_females])

# One-Hot encoding for classes
y_train_females = np.array(to_categorical(y_train_females, 8))
y_test_females = np.array(to_categorical(y_test_females, 8))

# %%
model = Sequential()

model.add(Conv2D(64, (5,5), input_shape=X_test_females.shape[1:], kernel_regularizer=l2(l=0.01)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(24, (4,4)))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(rate=0.1))

model.add(Conv2D(24, (3,3)))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(rate=0.2))

model.add(Conv2D(80, (2,2)))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(rate=0.5))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))

model.add(Dropout(rate=0.5))
model.add(Dense(8))
model.add(Activation('softmax'))

# %%
model.compile(
	optimizer="Adam",
	loss="categorical_crossentropy",
	metrics=['accuracy']
)

history = model.fit(
	x=X_train_females,
	y=y_train_females,
    epochs=100,
    batch_size=75,
    validation_data= (X_test_females, y_test_females)
)

score = model.evaluate(
	x=X_test_females,
	y=y_test_females)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/100
# 8/8 [==============================] - 3s 351ms/step - loss: 2.0989 - accuracy: 0.1319 - val_loss: 2.0944 - val_accuracy: 0.1458
# Epoch 2/100
# 8/8 [==============================] - 0s 28ms/step - loss: 2.0669 - accuracy: 0.1615 - val_loss: 2.0537 - val_accuracy: 0.2222
# Epoch 3/100
# 8/8 [==============================] - 0s 28ms/step - loss: 1.9619 - accuracy: 0.2552 - val_loss: 1.9075 - val_accuracy: 0.3750
# Epoch 4/100
# 8/8 [==============================] - 0s 28ms/step - loss: 1.8615 - accuracy: 0.3038 - val_loss: 1.8107 - val_accuracy: 0.3194
# Epoch 5/100
# 8/8 [==============================] - 0s 28ms/step - loss: 1.7336 - accuracy: 0.3472 - val_loss: 1.7703 - val_accuracy: 0.3333
# Epoch 6/100
# 8/8 [==============================] - 0s 28ms/step - loss: 1.6966 - accuracy: 0.3333 - val_loss: 1.6969 - val_accuracy: 0.3958
# Epoch 7/100
# 8/8 [==============================] - 0s 28ms/step - loss: 1.5516 - accuracy: 0.3993 - val_loss: 1.6083 - val_accuracy: 0.4167
# Epoch 8/100
# 8/8 [==============================] - 0s 28ms/step - loss: 1.4777 - accuracy: 0.4427 - val_loss: 1.5735 - val_accuracy: 0.4236
# Epoch 9/100
# 8/8 [==============================] - 0s 28ms/step - loss: 1.4229 - accuracy: 0.4931 - val_loss: 1.5700 - val_accuracy: 0.4583
# Epoch 10/100
# 8/8 [==============================] - 0s 28ms/step - loss: 1.2749 - accuracy: 0.5226 - val_loss: 1.5132 - val_accuracy: 0.4444
# Epoch 11/100
# 8/8 [==============================] - 0s 28ms/step - loss: 1.2606 - accuracy: 0.5521 - val_loss: 1.4734 - val_accuracy: 0.4722
# Epoch 12/100
# 8/8 [==============================] - 0s 28ms/step - loss: 1.1016 - accuracy: 0.5781 - val_loss: 1.3872 - val_accuracy: 0.4861
# Epoch 13/100
# 8/8 [==============================] - 0s 28ms/step - loss: 1.0333 - accuracy: 0.6215 - val_loss: 1.3573 - val_accuracy: 0.5069
# Epoch 14/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.9760 - accuracy: 0.6389 - val_loss: 1.3493 - val_accuracy: 0.5139
# Epoch 15/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.9010 - accuracy: 0.6562 - val_loss: 1.3721 - val_accuracy: 0.4931
# Epoch 16/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.8953 - accuracy: 0.6441 - val_loss: 1.3927 - val_accuracy: 0.4792
# Epoch 17/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.7592 - accuracy: 0.7153 - val_loss: 1.2811 - val_accuracy: 0.5069
# Epoch 18/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.7556 - accuracy: 0.7031 - val_loss: 1.3235 - val_accuracy: 0.5139
# Epoch 19/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.7637 - accuracy: 0.7135 - val_loss: 1.2879 - val_accuracy: 0.5208
# Epoch 20/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6720 - accuracy: 0.7830 - val_loss: 1.4095 - val_accuracy: 0.4931
# Epoch 21/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.7245 - accuracy: 0.7326 - val_loss: 1.2600 - val_accuracy: 0.5694
# Epoch 22/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6071 - accuracy: 0.7847 - val_loss: 1.3969 - val_accuracy: 0.5417
# Epoch 23/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6191 - accuracy: 0.7778 - val_loss: 1.3949 - val_accuracy: 0.5556
# Epoch 24/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.5409 - accuracy: 0.7934 - val_loss: 1.2752 - val_accuracy: 0.4931
# Epoch 25/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.5381 - accuracy: 0.7934 - val_loss: 1.3170 - val_accuracy: 0.5486
# Epoch 26/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4983 - accuracy: 0.8038 - val_loss: 1.5122 - val_accuracy: 0.5278
# Epoch 27/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4884 - accuracy: 0.8194 - val_loss: 1.2165 - val_accuracy: 0.5903
# Epoch 28/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4571 - accuracy: 0.8403 - val_loss: 1.3055 - val_accuracy: 0.5764
# Epoch 29/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3926 - accuracy: 0.8490 - val_loss: 1.3823 - val_accuracy: 0.5625
# Epoch 30/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4140 - accuracy: 0.8576 - val_loss: 1.4771 - val_accuracy: 0.5556
# Epoch 31/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4117 - accuracy: 0.8385 - val_loss: 1.4313 - val_accuracy: 0.5347
# Epoch 32/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4467 - accuracy: 0.8403 - val_loss: 1.3487 - val_accuracy: 0.5972
# Epoch 33/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3757 - accuracy: 0.8611 - val_loss: 1.2857 - val_accuracy: 0.6111
# Epoch 34/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3555 - accuracy: 0.8733 - val_loss: 1.5044 - val_accuracy: 0.5764
# Epoch 35/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3498 - accuracy: 0.8733 - val_loss: 1.5687 - val_accuracy: 0.5347
# Epoch 36/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3894 - accuracy: 0.8681 - val_loss: 1.4265 - val_accuracy: 0.5972
# Epoch 37/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3472 - accuracy: 0.8611 - val_loss: 1.4739 - val_accuracy: 0.5903
# Epoch 38/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3423 - accuracy: 0.8819 - val_loss: 1.5488 - val_accuracy: 0.5972
# Epoch 39/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3224 - accuracy: 0.8854 - val_loss: 1.4397 - val_accuracy: 0.6319
# Epoch 40/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3317 - accuracy: 0.8889 - val_loss: 1.3014 - val_accuracy: 0.6736
# Epoch 41/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3201 - accuracy: 0.8854 - val_loss: 1.3780 - val_accuracy: 0.6319
# Epoch 42/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3574 - accuracy: 0.8681 - val_loss: 1.3590 - val_accuracy: 0.6319
# Epoch 43/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3790 - accuracy: 0.8646 - val_loss: 1.3275 - val_accuracy: 0.6528
# Epoch 44/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3119 - accuracy: 0.8976 - val_loss: 1.2296 - val_accuracy: 0.6736
# Epoch 45/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3788 - accuracy: 0.8542 - val_loss: 1.2119 - val_accuracy: 0.6319
# Epoch 46/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3447 - accuracy: 0.8802 - val_loss: 1.3413 - val_accuracy: 0.6181
# Epoch 47/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3165 - accuracy: 0.8976 - val_loss: 1.4183 - val_accuracy: 0.6181
# Epoch 48/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3252 - accuracy: 0.8906 - val_loss: 1.4475 - val_accuracy: 0.6111
# Epoch 49/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3025 - accuracy: 0.8924 - val_loss: 1.4761 - val_accuracy: 0.5903
# Epoch 50/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3281 - accuracy: 0.8854 - val_loss: 1.5528 - val_accuracy: 0.5764
# Epoch 51/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2706 - accuracy: 0.8958 - val_loss: 1.4853 - val_accuracy: 0.6319
# Epoch 52/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2532 - accuracy: 0.9167 - val_loss: 1.5602 - val_accuracy: 0.6181
# Epoch 53/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2656 - accuracy: 0.9045 - val_loss: 1.4758 - val_accuracy: 0.6736
# Epoch 54/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2793 - accuracy: 0.9010 - val_loss: 1.7601 - val_accuracy: 0.6111
# Epoch 55/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3328 - accuracy: 0.8837 - val_loss: 1.5678 - val_accuracy: 0.6111
# Epoch 56/100
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2947 - accuracy: 0.8976 - val_loss: 1.3868 - val_accuracy: 0.6528
# Epoch 57/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2454 - accuracy: 0.9236 - val_loss: 1.6285 - val_accuracy: 0.5972
# Epoch 58/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2641 - accuracy: 0.9062 - val_loss: 1.5783 - val_accuracy: 0.6389
# Epoch 59/100
# 8/8 [==============================] - 0s 34ms/step - loss: 0.2660 - accuracy: 0.9097 - val_loss: 1.4340 - val_accuracy: 0.6319
# Epoch 60/100
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2606 - accuracy: 0.9097 - val_loss: 1.4080 - val_accuracy: 0.6111
# Epoch 61/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2625 - accuracy: 0.9080 - val_loss: 1.5494 - val_accuracy: 0.6111
# Epoch 62/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2460 - accuracy: 0.9132 - val_loss: 1.2788 - val_accuracy: 0.7014
# Epoch 63/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2141 - accuracy: 0.9271 - val_loss: 1.3701 - val_accuracy: 0.6597
# Epoch 64/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2033 - accuracy: 0.9201 - val_loss: 1.5661 - val_accuracy: 0.6389
# Epoch 65/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2541 - accuracy: 0.9132 - val_loss: 1.4142 - val_accuracy: 0.7083
# Epoch 66/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2294 - accuracy: 0.9201 - val_loss: 1.3685 - val_accuracy: 0.6319
# Epoch 67/100
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2537 - accuracy: 0.9115 - val_loss: 1.4064 - val_accuracy: 0.6458
# Epoch 68/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2595 - accuracy: 0.8958 - val_loss: 1.6294 - val_accuracy: 0.6597
# Epoch 69/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2726 - accuracy: 0.8976 - val_loss: 1.4135 - val_accuracy: 0.6667
# Epoch 70/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2096 - accuracy: 0.9184 - val_loss: 1.4389 - val_accuracy: 0.6528
# Epoch 71/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2055 - accuracy: 0.9392 - val_loss: 1.6193 - val_accuracy: 0.6597
# Epoch 72/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2440 - accuracy: 0.9236 - val_loss: 1.6161 - val_accuracy: 0.5972
# Epoch 73/100
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2514 - accuracy: 0.9045 - val_loss: 1.4616 - val_accuracy: 0.6389
# Epoch 74/100
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1939 - accuracy: 0.9340 - val_loss: 1.5732 - val_accuracy: 0.6389
# Epoch 75/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2368 - accuracy: 0.9340 - val_loss: 1.6051 - val_accuracy: 0.6528
# Epoch 76/100
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1977 - accuracy: 0.9358 - val_loss: 1.7218 - val_accuracy: 0.6042
# Epoch 77/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2030 - accuracy: 0.9184 - val_loss: 1.7394 - val_accuracy: 0.6319
# Epoch 78/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2519 - accuracy: 0.9167 - val_loss: 1.5919 - val_accuracy: 0.6667
# Epoch 79/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2427 - accuracy: 0.9115 - val_loss: 1.5986 - val_accuracy: 0.6806
# Epoch 80/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2408 - accuracy: 0.9253 - val_loss: 1.5434 - val_accuracy: 0.6319
# Epoch 81/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2083 - accuracy: 0.9201 - val_loss: 1.3682 - val_accuracy: 0.6667
# Epoch 82/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1874 - accuracy: 0.9358 - val_loss: 1.5000 - val_accuracy: 0.6528
# Epoch 83/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1766 - accuracy: 0.9375 - val_loss: 1.8838 - val_accuracy: 0.6319
# Epoch 84/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1951 - accuracy: 0.9358 - val_loss: 1.6060 - val_accuracy: 0.6806
# Epoch 85/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1609 - accuracy: 0.9479 - val_loss: 1.5439 - val_accuracy: 0.6667
# Epoch 86/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1913 - accuracy: 0.9392 - val_loss: 1.5933 - val_accuracy: 0.6389
# Epoch 87/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2142 - accuracy: 0.9358 - val_loss: 1.5171 - val_accuracy: 0.6250
# Epoch 88/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2117 - accuracy: 0.9236 - val_loss: 1.2896 - val_accuracy: 0.7014
# Epoch 89/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1744 - accuracy: 0.9340 - val_loss: 1.4183 - val_accuracy: 0.6597
# Epoch 90/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1934 - accuracy: 0.9306 - val_loss: 1.6865 - val_accuracy: 0.6111
# Epoch 91/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2200 - accuracy: 0.9288 - val_loss: 1.4720 - val_accuracy: 0.7222
# Epoch 92/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1755 - accuracy: 0.9392 - val_loss: 1.4247 - val_accuracy: 0.6667
# Epoch 93/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1809 - accuracy: 0.9306 - val_loss: 1.4563 - val_accuracy: 0.6319
# Epoch 94/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2212 - accuracy: 0.9132 - val_loss: 1.5560 - val_accuracy: 0.6667
# Epoch 95/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1845 - accuracy: 0.9479 - val_loss: 1.4651 - val_accuracy: 0.7014
# Epoch 96/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2250 - accuracy: 0.9236 - val_loss: 1.3991 - val_accuracy: 0.6806
# Epoch 97/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1533 - accuracy: 0.9444 - val_loss: 1.4530 - val_accuracy: 0.6875
# Epoch 98/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1421 - accuracy: 0.9497 - val_loss: 1.7025 - val_accuracy: 0.6181
# Epoch 99/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1805 - accuracy: 0.9427 - val_loss: 1.8273 - val_accuracy: 0.6250
# Epoch 100/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1856 - accuracy: 0.9340 - val_loss: 1.5620 - val_accuracy: 0.6597
# 5/5 [==============================] - 0s 22ms/step - loss: 1.5620 - accuracy: 0.6597
# Test loss: 1.5620092153549194
# Test accuracy: 0.6597222089767456

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Female Data Training and Validation Accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Female Data Training and Validation Loss')
plt.legend()
plt.show()
