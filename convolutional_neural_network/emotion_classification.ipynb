# %% [markdown]
# # Convolutional Neural Network Using Mel Spectrogram Classifying Gender

# %%
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Flatten, Conv2D, MaxPooling2D, LeakyReLU
from keras.optimizers import SGD
from keras.utils import to_categorical
from keras.regularizers import l2
from sklearn.preprocessing import MinMaxScaler
import librosa
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %matplotlib inline

# %%
audio_data = np.load("../data/audio_data.npy")
labels = np.load("../data/wav_labels.npy")

# labels: modality-vocal channel-emotion-emotional intensity-statement-repetition-actor
# emotions: 01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised
# odd number actors = male, even = female

# 1440 files: 24 speakers, 60 recordings per speaker
audio_data = audio_data.reshape(1440, 9480)

features = []

for i in range(1440):
    
    if (labels[i][6]%2 == 0):
        label = "Female"
    else:
        label = "Male"

for i in range(1440):
    if (labels[i][2] == 1):
        em = 0
    elif (labels[i][2] == 2):
        em = 1
    elif (labels[i][2] == 3):
        em = 2
    elif (labels[i][2] == 4):
        em = 3
    elif (labels[i][2] == 5):
        em = 4
    elif (labels[i][2] == 6):
        em = 5
    elif (labels[i][2] == 7):
        em = 6
    elif (labels[i][2] == 8):
        em = 7
    
    features.append([audio_data[i], label, em])
    
feature_df = pd.DataFrame(features, columns = ["mfcc", "gender", "emotion"])

feature_df.head()
# Out:
#                                                 mfcc  gender  emotion
# 0  [-855.3770751953125, -855.3770751953125, -855....  Female        0
# 1  [-850.3917236328125, -850.435791015625, -850.4...  Female        0
# 2  [-849.78369140625, -848.8447265625, -848.56610...  Female        0
# 3  [-842.9385375976562, -843.2474975585938, -850....  Female        0
# 4  [-911.1758422851562, -910.4053344726562, -905....  Female        1

# %%
#split data - males vs females
mal = feature_df.loc[feature_df['gender'] == "Male"]
fem = feature_df.loc[feature_df['gender'] == "Female"]

## ===== Females ===== ##
X_females_unscaled = np.array(fem.mfcc.tolist())
y_females = np.array(fem.emotion.tolist())

scaler = MinMaxScaler(feature_range=(-1,1))
scaler.fit(X_females_unscaled)
X_females_scaled = scaler.transform(X_females_unscaled)

#20-80 train-test split
X_train_females, X_test_females, y_train_females, y_test_females = train_test_split(X_females_scaled, y_females, test_size=0.20, random_state=0)

# %%
# Reshape for CNN input
X_train_females = np.array([x.reshape( (20, 474, 1) ) for x in X_train_females])
X_test_females = np.array([x.reshape( (20, 474, 1) ) for x in X_test_females])

# One-Hot encoding for classes
y_train_females = np.array(to_categorical(y_train_females, 8))
y_test_females = np.array(to_categorical(y_test_females, 8))

# %%
model = Sequential()

model.add(Conv2D(64, (5,5), input_shape=X_test_females.shape[1:], kernel_regularizer=l2(l=0.01)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(24, (4,4)))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(rate=0.1))

model.add(Conv2D(24, (3,3)))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(rate=0.2))

model.add(Conv2D(80, (2,2)))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(rate=0.5))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))

model.add(Dropout(rate=0.5))
model.add(Dense(8))
model.add(Activation('softmax'))

# %%
model.compile(
	optimizer="Adam",
	loss="categorical_crossentropy",
	metrics=['accuracy']
)

history = model.fit(
	x=X_train_females,
	y=y_train_females,
    epochs=150,
    batch_size=75,
    validation_data=(X_test_females, y_test_females)
)

y_pred = model.predict(X_test_females)

score = model.evaluate(
	x=X_test_females,
	y=y_test_females)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/150
# 16/16 [==============================] - 1s 92ms/step - loss: 2.0794 - accuracy: 0.1302 - val_loss: 2.0368 - val_accuracy: 0.2743
# Epoch 2/150
# 16/16 [==============================] - 0s 27ms/step - loss: 1.9829 - accuracy: 0.2283 - val_loss: 1.9215 - val_accuracy: 0.2396
# Epoch 3/150
# 16/16 [==============================] - 0s 27ms/step - loss: 1.8569 - accuracy: 0.2604 - val_loss: 1.8065 - val_accuracy: 0.3785
# Epoch 4/150
# 16/16 [==============================] - 0s 27ms/step - loss: 1.7483 - accuracy: 0.3342 - val_loss: 1.6858 - val_accuracy: 0.3854
# Epoch 5/150
# 16/16 [==============================] - 0s 27ms/step - loss: 1.6198 - accuracy: 0.3889 - val_loss: 1.6286 - val_accuracy: 0.3889
# Epoch 6/150
# 16/16 [==============================] - 0s 27ms/step - loss: 1.5149 - accuracy: 0.4297 - val_loss: 1.5306 - val_accuracy: 0.4444
# Epoch 7/150
# 16/16 [==============================] - 0s 27ms/step - loss: 1.4285 - accuracy: 0.4549 - val_loss: 1.5178 - val_accuracy: 0.4479
# Epoch 8/150
# 16/16 [==============================] - 0s 27ms/step - loss: 1.3297 - accuracy: 0.5000 - val_loss: 1.3913 - val_accuracy: 0.4861
# Epoch 9/150
# 16/16 [==============================] - 0s 27ms/step - loss: 1.2742 - accuracy: 0.5243 - val_loss: 1.3285 - val_accuracy: 0.5382
# Epoch 10/150
# 16/16 [==============================] - 0s 27ms/step - loss: 1.2025 - accuracy: 0.5443 - val_loss: 1.3084 - val_accuracy: 0.5382
# Epoch 11/150
# 16/16 [==============================] - 0s 27ms/step - loss: 1.1586 - accuracy: 0.5764 - val_loss: 1.3075 - val_accuracy: 0.5556
# Epoch 12/150
# 16/16 [==============================] - 0s 27ms/step - loss: 1.0865 - accuracy: 0.6094 - val_loss: 1.2332 - val_accuracy: 0.5590
# Epoch 13/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.9822 - accuracy: 0.6163 - val_loss: 1.2250 - val_accuracy: 0.5590
# Epoch 14/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.9268 - accuracy: 0.6589 - val_loss: 1.2547 - val_accuracy: 0.5694
# Epoch 15/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.8824 - accuracy: 0.6814 - val_loss: 1.2090 - val_accuracy: 0.5938
# Epoch 16/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.8193 - accuracy: 0.6997 - val_loss: 1.2123 - val_accuracy: 0.5938
# Epoch 17/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.7636 - accuracy: 0.7188 - val_loss: 1.2688 - val_accuracy: 0.5764
# Epoch 18/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.7497 - accuracy: 0.7292 - val_loss: 1.2260 - val_accuracy: 0.5938
# Epoch 19/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.6840 - accuracy: 0.7595 - val_loss: 1.2438 - val_accuracy: 0.6042
# Epoch 20/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.7084 - accuracy: 0.7335 - val_loss: 1.2141 - val_accuracy: 0.6215
# Epoch 21/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.6856 - accuracy: 0.7431 - val_loss: 1.2720 - val_accuracy: 0.5799
# Epoch 22/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.5855 - accuracy: 0.7917 - val_loss: 1.3124 - val_accuracy: 0.6042
# Epoch 23/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.6448 - accuracy: 0.7604 - val_loss: 1.2824 - val_accuracy: 0.5938
# Epoch 24/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.5579 - accuracy: 0.8003 - val_loss: 1.2463 - val_accuracy: 0.6181
# Epoch 25/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.5657 - accuracy: 0.7908 - val_loss: 1.3420 - val_accuracy: 0.6285
# Epoch 26/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.5151 - accuracy: 0.8003 - val_loss: 1.3758 - val_accuracy: 0.6285
# Epoch 27/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.5201 - accuracy: 0.8082 - val_loss: 1.4380 - val_accuracy: 0.6181
# Epoch 28/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.4722 - accuracy: 0.8325 - val_loss: 1.3923 - val_accuracy: 0.6389
# Epoch 29/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.4545 - accuracy: 0.8342 - val_loss: 1.4818 - val_accuracy: 0.6215
# Epoch 30/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.4679 - accuracy: 0.8281 - val_loss: 1.4202 - val_accuracy: 0.6389
# Epoch 31/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.4434 - accuracy: 0.8299 - val_loss: 1.3723 - val_accuracy: 0.6389
# Epoch 32/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.4257 - accuracy: 0.8516 - val_loss: 1.5582 - val_accuracy: 0.5799
# Epoch 33/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.4515 - accuracy: 0.8290 - val_loss: 1.4836 - val_accuracy: 0.6215
# Epoch 34/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.4016 - accuracy: 0.8516 - val_loss: 1.4490 - val_accuracy: 0.6146
# Epoch 35/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.3869 - accuracy: 0.8481 - val_loss: 1.4944 - val_accuracy: 0.6354
# Epoch 36/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.4201 - accuracy: 0.8472 - val_loss: 1.5175 - val_accuracy: 0.6111
# Epoch 37/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3973 - accuracy: 0.8516 - val_loss: 1.5453 - val_accuracy: 0.6181
# Epoch 38/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3705 - accuracy: 0.8724 - val_loss: 1.6006 - val_accuracy: 0.6458
# Epoch 39/150
# 16/16 [==============================] - 0s 29ms/step - loss: 0.3811 - accuracy: 0.8785 - val_loss: 1.5590 - val_accuracy: 0.6146
# Epoch 40/150
# 16/16 [==============================] - 0s 29ms/step - loss: 0.3393 - accuracy: 0.8793 - val_loss: 1.5075 - val_accuracy: 0.6424
# Epoch 41/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3536 - accuracy: 0.8707 - val_loss: 1.6312 - val_accuracy: 0.6181
# Epoch 42/150
# 16/16 [==============================] - 0s 26ms/step - loss: 0.3288 - accuracy: 0.8724 - val_loss: 1.6355 - val_accuracy: 0.6354
# Epoch 43/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3563 - accuracy: 0.8819 - val_loss: 1.6392 - val_accuracy: 0.6076
# Epoch 44/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3337 - accuracy: 0.8785 - val_loss: 1.7033 - val_accuracy: 0.6250
# Epoch 45/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3772 - accuracy: 0.8663 - val_loss: 1.5751 - val_accuracy: 0.6250
# Epoch 46/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.3037 - accuracy: 0.8950 - val_loss: 1.6091 - val_accuracy: 0.6389
# Epoch 47/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3355 - accuracy: 0.8915 - val_loss: 1.7135 - val_accuracy: 0.6389
# Epoch 48/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3030 - accuracy: 0.8976 - val_loss: 1.6376 - val_accuracy: 0.6389
# Epoch 49/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3111 - accuracy: 0.8976 - val_loss: 1.5808 - val_accuracy: 0.6319
# Epoch 50/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.3096 - accuracy: 0.8915 - val_loss: 1.6873 - val_accuracy: 0.6632
# Epoch 51/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3028 - accuracy: 0.8837 - val_loss: 1.8299 - val_accuracy: 0.6319
# Epoch 52/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2751 - accuracy: 0.8984 - val_loss: 1.7152 - val_accuracy: 0.6285
# Epoch 53/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2981 - accuracy: 0.8984 - val_loss: 1.8055 - val_accuracy: 0.6458
# Epoch 54/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3030 - accuracy: 0.8889 - val_loss: 1.6056 - val_accuracy: 0.6319
# Epoch 55/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2711 - accuracy: 0.9054 - val_loss: 1.7160 - val_accuracy: 0.6389
# Epoch 56/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3060 - accuracy: 0.8906 - val_loss: 1.7924 - val_accuracy: 0.6250
# Epoch 57/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2710 - accuracy: 0.9062 - val_loss: 1.8690 - val_accuracy: 0.6319
# Epoch 58/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2871 - accuracy: 0.9045 - val_loss: 1.7021 - val_accuracy: 0.6597
# Epoch 59/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2709 - accuracy: 0.8984 - val_loss: 2.0408 - val_accuracy: 0.6250
# Epoch 60/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2824 - accuracy: 0.8984 - val_loss: 1.7416 - val_accuracy: 0.6215
# Epoch 61/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.3010 - accuracy: 0.8924 - val_loss: 1.7472 - val_accuracy: 0.6458
# Epoch 62/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2310 - accuracy: 0.9332 - val_loss: 1.8871 - val_accuracy: 0.6250
# Epoch 63/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2553 - accuracy: 0.9167 - val_loss: 1.7952 - val_accuracy: 0.6319
# Epoch 64/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2359 - accuracy: 0.9149 - val_loss: 1.8281 - val_accuracy: 0.6389
# Epoch 65/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2247 - accuracy: 0.9236 - val_loss: 1.9097 - val_accuracy: 0.6250
# Epoch 66/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2678 - accuracy: 0.9123 - val_loss: 1.6891 - val_accuracy: 0.6562
# Epoch 67/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2388 - accuracy: 0.9149 - val_loss: 1.6151 - val_accuracy: 0.6493
# Epoch 68/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2209 - accuracy: 0.9149 - val_loss: 2.0300 - val_accuracy: 0.6319
# Epoch 69/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2844 - accuracy: 0.9010 - val_loss: 1.7412 - val_accuracy: 0.6493
# Epoch 70/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2462 - accuracy: 0.9123 - val_loss: 1.7966 - val_accuracy: 0.6354
# Epoch 71/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2334 - accuracy: 0.9193 - val_loss: 1.8833 - val_accuracy: 0.6146
# Epoch 72/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2295 - accuracy: 0.9106 - val_loss: 1.8933 - val_accuracy: 0.6389
# Epoch 73/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2064 - accuracy: 0.9262 - val_loss: 1.6869 - val_accuracy: 0.6319
# Epoch 74/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1827 - accuracy: 0.9340 - val_loss: 1.9725 - val_accuracy: 0.6667
# Epoch 75/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2045 - accuracy: 0.9314 - val_loss: 1.9760 - val_accuracy: 0.6389
# Epoch 76/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2009 - accuracy: 0.9262 - val_loss: 2.0210 - val_accuracy: 0.6285
# Epoch 77/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2535 - accuracy: 0.9071 - val_loss: 1.8856 - val_accuracy: 0.6250
# Epoch 78/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2021 - accuracy: 0.9323 - val_loss: 1.9530 - val_accuracy: 0.6493
# Epoch 79/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1984 - accuracy: 0.9375 - val_loss: 1.9453 - val_accuracy: 0.6562
# Epoch 80/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2116 - accuracy: 0.9193 - val_loss: 1.9361 - val_accuracy: 0.6354
# Epoch 81/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1909 - accuracy: 0.9340 - val_loss: 1.9921 - val_accuracy: 0.6389
# Epoch 82/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2091 - accuracy: 0.9280 - val_loss: 2.0286 - val_accuracy: 0.6701
# Epoch 83/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2096 - accuracy: 0.9288 - val_loss: 1.8907 - val_accuracy: 0.6285
# Epoch 84/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2005 - accuracy: 0.9349 - val_loss: 2.0537 - val_accuracy: 0.6389
# Epoch 85/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1747 - accuracy: 0.9349 - val_loss: 2.0838 - val_accuracy: 0.6215
# Epoch 86/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1942 - accuracy: 0.9384 - val_loss: 2.1024 - val_accuracy: 0.6424
# Epoch 87/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1987 - accuracy: 0.9358 - val_loss: 2.1641 - val_accuracy: 0.6562
# Epoch 88/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2057 - accuracy: 0.9288 - val_loss: 1.9891 - val_accuracy: 0.6667
# Epoch 89/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1838 - accuracy: 0.9349 - val_loss: 1.9056 - val_accuracy: 0.6597
# Epoch 90/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1780 - accuracy: 0.9332 - val_loss: 2.1559 - val_accuracy: 0.6354
# Epoch 91/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1817 - accuracy: 0.9332 - val_loss: 1.9800 - val_accuracy: 0.6562
# Epoch 92/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1764 - accuracy: 0.9410 - val_loss: 1.9564 - val_accuracy: 0.6424
# Epoch 93/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1846 - accuracy: 0.9314 - val_loss: 2.0416 - val_accuracy: 0.6458
# Epoch 94/150
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1939 - accuracy: 0.9314 - val_loss: 1.9656 - val_accuracy: 0.6215
# Epoch 95/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2018 - accuracy: 0.9392 - val_loss: 1.9534 - val_accuracy: 0.6493
# Epoch 96/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2223 - accuracy: 0.9245 - val_loss: 1.8621 - val_accuracy: 0.6632
# Epoch 97/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2499 - accuracy: 0.9175 - val_loss: 2.1418 - val_accuracy: 0.6215
# Epoch 98/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1999 - accuracy: 0.9375 - val_loss: 2.1473 - val_accuracy: 0.6389
# Epoch 99/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1807 - accuracy: 0.9349 - val_loss: 1.9242 - val_accuracy: 0.6424
# Epoch 100/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2014 - accuracy: 0.9323 - val_loss: 2.1928 - val_accuracy: 0.6528
# Epoch 101/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1571 - accuracy: 0.9479 - val_loss: 2.0551 - val_accuracy: 0.6354
# Epoch 102/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1656 - accuracy: 0.9366 - val_loss: 2.1481 - val_accuracy: 0.6528
# Epoch 103/150
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1542 - accuracy: 0.9427 - val_loss: 2.0976 - val_accuracy: 0.6458
# Epoch 104/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1824 - accuracy: 0.9401 - val_loss: 1.8784 - val_accuracy: 0.6875
# Epoch 105/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1646 - accuracy: 0.9479 - val_loss: 2.0247 - val_accuracy: 0.6562
# Epoch 106/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1781 - accuracy: 0.9392 - val_loss: 2.1578 - val_accuracy: 0.6458
# Epoch 107/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1603 - accuracy: 0.9557 - val_loss: 1.9405 - val_accuracy: 0.6701
# Epoch 108/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1653 - accuracy: 0.9514 - val_loss: 2.4310 - val_accuracy: 0.6458
# Epoch 109/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1843 - accuracy: 0.9314 - val_loss: 2.1051 - val_accuracy: 0.6701
# Epoch 110/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1698 - accuracy: 0.9392 - val_loss: 2.0619 - val_accuracy: 0.6424
# Epoch 111/150
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1919 - accuracy: 0.9375 - val_loss: 2.0958 - val_accuracy: 0.6562
# Epoch 112/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1839 - accuracy: 0.9358 - val_loss: 1.9805 - val_accuracy: 0.6597
# Epoch 113/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1660 - accuracy: 0.9436 - val_loss: 2.1069 - val_accuracy: 0.6458
# Epoch 114/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1758 - accuracy: 0.9375 - val_loss: 2.1217 - val_accuracy: 0.6736
# Epoch 115/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1558 - accuracy: 0.9401 - val_loss: 2.1897 - val_accuracy: 0.6389
# Epoch 116/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1487 - accuracy: 0.9497 - val_loss: 2.3809 - val_accuracy: 0.6493
# Epoch 117/150
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1824 - accuracy: 0.9384 - val_loss: 2.0716 - val_accuracy: 0.6493
# Epoch 118/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1558 - accuracy: 0.9392 - val_loss: 2.2602 - val_accuracy: 0.6528
# Epoch 119/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1404 - accuracy: 0.9488 - val_loss: 2.2895 - val_accuracy: 0.6424
# Epoch 120/150
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1863 - accuracy: 0.9297 - val_loss: 1.9920 - val_accuracy: 0.6354
# Epoch 121/150
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1546 - accuracy: 0.9418 - val_loss: 2.1266 - val_accuracy: 0.6597
# Epoch 122/150
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1891 - accuracy: 0.9332 - val_loss: 2.0390 - val_accuracy: 0.6528
# Epoch 123/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1538 - accuracy: 0.9488 - val_loss: 2.0969 - val_accuracy: 0.6458
# Epoch 124/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1397 - accuracy: 0.9549 - val_loss: 2.3593 - val_accuracy: 0.6493
# Epoch 125/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1439 - accuracy: 0.9531 - val_loss: 2.3350 - val_accuracy: 0.6597
# Epoch 126/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1920 - accuracy: 0.9323 - val_loss: 1.9450 - val_accuracy: 0.6736
# Epoch 127/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1543 - accuracy: 0.9436 - val_loss: 2.1628 - val_accuracy: 0.6319
# Epoch 128/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1541 - accuracy: 0.9497 - val_loss: 2.1450 - val_accuracy: 0.6667
# Epoch 129/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1538 - accuracy: 0.9453 - val_loss: 2.2076 - val_accuracy: 0.6701
# Epoch 130/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1262 - accuracy: 0.9566 - val_loss: 2.4069 - val_accuracy: 0.6354
# Epoch 131/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1722 - accuracy: 0.9375 - val_loss: 2.3982 - val_accuracy: 0.6667
# Epoch 132/150
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1441 - accuracy: 0.9523 - val_loss: 2.2349 - val_accuracy: 0.6562
# Epoch 133/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1376 - accuracy: 0.9549 - val_loss: 2.1495 - val_accuracy: 0.6528
# Epoch 134/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1619 - accuracy: 0.9479 - val_loss: 2.1284 - val_accuracy: 0.6701
# Epoch 135/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1301 - accuracy: 0.9566 - val_loss: 2.0848 - val_accuracy: 0.6979
# Epoch 136/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1421 - accuracy: 0.9540 - val_loss: 2.1647 - val_accuracy: 0.6806
# Epoch 137/150
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1242 - accuracy: 0.9488 - val_loss: 2.1750 - val_accuracy: 0.6701
# Epoch 138/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1385 - accuracy: 0.9549 - val_loss: 2.1800 - val_accuracy: 0.6597
# Epoch 139/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1365 - accuracy: 0.9462 - val_loss: 2.1825 - val_accuracy: 0.6701
# Epoch 140/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1280 - accuracy: 0.9531 - val_loss: 2.2969 - val_accuracy: 0.6736
# Epoch 141/150
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1472 - accuracy: 0.9488 - val_loss: 2.2987 - val_accuracy: 0.6667
# Epoch 142/150
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1116 - accuracy: 0.9627 - val_loss: 2.2576 - val_accuracy: 0.6771
# Epoch 143/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1357 - accuracy: 0.9505 - val_loss: 2.3551 - val_accuracy: 0.6354
# Epoch 144/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1328 - accuracy: 0.9601 - val_loss: 2.3015 - val_accuracy: 0.6528
# Epoch 145/150
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1481 - accuracy: 0.9540 - val_loss: 2.2627 - val_accuracy: 0.6944
# Epoch 146/150
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1318 - accuracy: 0.9523 - val_loss: 2.2608 - val_accuracy: 0.6632
# Epoch 147/150
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1536 - accuracy: 0.9479 - val_loss: 2.2920 - val_accuracy: 0.6771
# Epoch 148/150
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1515 - accuracy: 0.9410 - val_loss: 2.4181 - val_accuracy: 0.6562
# Epoch 149/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1536 - accuracy: 0.9462 - val_loss: 2.4524 - val_accuracy: 0.6701
# Epoch 150/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1357 - accuracy: 0.9566 - val_loss: 2.3820 - val_accuracy: 0.6701
# 9/9 [==============================] - 0s 5ms/step - loss: 2.3820 - accuracy: 0.6701
# Test loss: 2.3820133209228516
# Test accuracy: 0.6701388955116272

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Female Data Training and Validation Accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Female Data Training and Validation Loss')
plt.legend()
plt.show()

# %%
#Algorithm Evaluation
cm = confusion_matrix(y_test_females.argmax(axis=1), y_pred.argmax(axis=1))
print("CNN Female Emotion Classification")
df = pd.DataFrame(cm, columns=[y_females[0], y_females[4], y_females[12], y_females[20], y_females[28], y_females[36], y_females[44], y_females[52] ])
print(df)

#figure for confusion matrix
cm = confusion_matrix(y_test_females.argmax(axis=1), y_pred.argmax(axis=1))
plt.figure(figsize=(10,4))
plt.imshow(cm)
plt.title("CNN Female Emotion Classification")
plt.show()

#precision function
def precision(confmatrix):
    # precision = tp/(tp+fp)
    tp = np.diag(confmatrix)
    fp = np.sum(confmatrix, axis=0) - tp
    precision = np.mean(tp/(tp+fp))
    return precision

prec = precision(cm)
# Out:
# CNN Female Emotion Classification
#     0   1   2   3   4   5   6   7
# 0  16   2   1   5   1   0   0   0
# 1   6  29   1   7   0   0   1   0
# 2   0   0  25   4   0   1   1   2
# 3   1   5   3  24   0   4   0   1
# 4   0   1   2   1  26   0   2   2
# 5   0   1   3   3   1  29   1   3
# 6   0   2   2   4   2   2  19   0
# 7   0   0   5   4   3   1   4  25
