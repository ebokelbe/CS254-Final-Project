# %% [markdown]
# # Convolutional Neural Network Using Mel Spectrogram Classifying Gender

# %%
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Flatten, Conv2D, MaxPooling2D, LeakyReLU
from keras.optimizers import SGD
from keras.utils import to_categorical
from keras.regularizers import l2
from sklearn.preprocessing import MinMaxScaler
import librosa
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
audio_data = np.load("../data/audio_data.npy")
labels = np.load("../data/wav_labels.npy")

# labels: modality-vocal channel-emotion-emotional intensity-statement-repetition-actor
# emotions: 01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised
# odd number actors = male, even = female

# 1440 files: 24 speakers, 60 recordings per speaker
audio_data = audio_data.reshape(1440, 9480)

features = []

for i in range(1440):
    
    if (labels[i][6]%2 == 0):
        label = "Female"
    else:
        label = "Male"

    if (labels[i][2] == 1):
        em = 0
    elif (labels[i][2] == 2):
        em = 1
    elif (labels[i][2] == 3):
        em = 2
    elif (labels[i][2] == 4):
        em = 3
    elif (labels[i][2] == 5):
        em = 4
    elif (labels[i][2] == 6):
        em = 5
    elif (labels[i][2] == 7):
        em = 6
    elif (labels[i][2] == 8):
        em = 7
    
    features.append([audio_data[i], label, em])
    
feature_df = pd.DataFrame(features, columns = ["mfcc", "gender", "emotion"])

feature_df.head()
# Out:
#                                                 mfcc gender  emotion
# 0  [-855.3770751953125, -855.3770751953125, -855....   Male        0
# 1  [-850.3917236328125, -850.435791015625, -850.4...   Male        0
# 2  [-849.78369140625, -848.8447265625, -848.56610...   Male        0
# 3  [-842.9385375976562, -843.2474975585938, -850....   Male        0
# 4  [-911.1758422851562, -910.4053344726562, -905....   Male        1

# %%
#split data - males vs females
mal = feature_df.loc[feature_df['gender'] == "Male"]
fem = feature_df.loc[feature_df['gender'] == "Female"]

## ===== Females ===== ##
X_females_unscaled = np.array(fem.mfcc.tolist())
y_females = np.array(fem.emotion.tolist())

scaler = MinMaxScaler(feature_range=(-1,1))
scaler.fit(X_females_unscaled)
X_females_scaled = scaler.transform(X_females_unscaled)

#20-80 train-test split
X_train_females, X_test_females, y_train_females, y_test_females = train_test_split(X_females_scaled, y_females, test_size=0.20, random_state=0)

# %%
# Reshape for CNN input
X_train_females = np.array([x.reshape( (20, 474, 1) ) for x in X_train_females])
X_test_females = np.array([x.reshape( (20, 474, 1) ) for x in X_test_females])

# One-Hot encoding for classes
y_train_females = np.array(to_categorical(y_train_females, 8))
y_test_females = np.array(to_categorical(y_test_females, 8))

# %%
model = Sequential()

model.add(Conv2D(64, (5,5), input_shape=X_test_females.shape[1:], kernel_regularizer=l2(l=0.01)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(24, (4,4)))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(rate=0.1))

model.add(Conv2D(24, (3,3)))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(rate=0.2))

model.add(Conv2D(80, (2,2)))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(rate=0.5))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))

model.add(Dropout(rate=0.5))
model.add(Dense(8))
model.add(Activation('softmax'))

# %%
model.compile(
	optimizer="Adam",
	loss="categorical_crossentropy",
	metrics=['accuracy']
)

history = model.fit(
	x=X_train_females,
	y=y_train_females,
    epochs=100,
    batch_size=75,
    validation_data= (X_test_females, y_test_females)
)

score = model.evaluate(
	x=X_test_females,
	y=y_test_females)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/100
# 8/8 [==============================] - 1s 180ms/step - loss: 2.0952 - accuracy: 0.1458 - val_loss: 2.0876 - val_accuracy: 0.1319
# Epoch 2/100
# 8/8 [==============================] - 0s 30ms/step - loss: 2.0773 - accuracy: 0.1424 - val_loss: 2.0790 - val_accuracy: 0.2292
# Epoch 3/100
# 8/8 [==============================] - 0s 29ms/step - loss: 2.0520 - accuracy: 0.1927 - val_loss: 2.0554 - val_accuracy: 0.2778
# Epoch 4/100
# 8/8 [==============================] - 0s 28ms/step - loss: 1.9961 - accuracy: 0.2274 - val_loss: 1.9900 - val_accuracy: 0.2708
# Epoch 5/100
# 8/8 [==============================] - 0s 31ms/step - loss: 1.9149 - accuracy: 0.2847 - val_loss: 1.8731 - val_accuracy: 0.3472
# Epoch 6/100
# 8/8 [==============================] - 0s 29ms/step - loss: 1.7849 - accuracy: 0.3003 - val_loss: 1.7349 - val_accuracy: 0.4028
# Epoch 7/100
# 8/8 [==============================] - 0s 29ms/step - loss: 1.6880 - accuracy: 0.3628 - val_loss: 1.7053 - val_accuracy: 0.3750
# Epoch 8/100
# 8/8 [==============================] - 0s 28ms/step - loss: 1.6125 - accuracy: 0.4149 - val_loss: 1.6021 - val_accuracy: 0.5139
# Epoch 9/100
# 8/8 [==============================] - 0s 28ms/step - loss: 1.5028 - accuracy: 0.4201 - val_loss: 1.5217 - val_accuracy: 0.5486
# Epoch 10/100
# 8/8 [==============================] - 0s 28ms/step - loss: 1.4189 - accuracy: 0.4809 - val_loss: 1.5222 - val_accuracy: 0.5208
# Epoch 11/100
# 8/8 [==============================] - 0s 27ms/step - loss: 1.3025 - accuracy: 0.5243 - val_loss: 1.3807 - val_accuracy: 0.5069
# Epoch 12/100
# 8/8 [==============================] - 0s 27ms/step - loss: 1.1862 - accuracy: 0.5573 - val_loss: 1.3597 - val_accuracy: 0.5764
# Epoch 13/100
# 8/8 [==============================] - 0s 28ms/step - loss: 1.1453 - accuracy: 0.6042 - val_loss: 1.2515 - val_accuracy: 0.5972
# Epoch 14/100
# 8/8 [==============================] - 0s 28ms/step - loss: 1.0562 - accuracy: 0.5868 - val_loss: 1.2893 - val_accuracy: 0.5556
# Epoch 15/100
# 8/8 [==============================] - 0s 30ms/step - loss: 1.0561 - accuracy: 0.6163 - val_loss: 1.2117 - val_accuracy: 0.5903
# Epoch 16/100
# 8/8 [==============================] - 0s 30ms/step - loss: 0.9238 - accuracy: 0.6372 - val_loss: 1.1391 - val_accuracy: 0.6250
# Epoch 17/100
# 8/8 [==============================] - 0s 30ms/step - loss: 0.8664 - accuracy: 0.6840 - val_loss: 1.1743 - val_accuracy: 0.6458
# Epoch 18/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.8342 - accuracy: 0.6927 - val_loss: 1.2033 - val_accuracy: 0.5903
# Epoch 19/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.7426 - accuracy: 0.7326 - val_loss: 1.1173 - val_accuracy: 0.6458
# Epoch 20/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6883 - accuracy: 0.7622 - val_loss: 1.1406 - val_accuracy: 0.5972
# Epoch 21/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6701 - accuracy: 0.7465 - val_loss: 1.1081 - val_accuracy: 0.6528
# Epoch 22/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6746 - accuracy: 0.7465 - val_loss: 1.1321 - val_accuracy: 0.6111
# Epoch 23/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6526 - accuracy: 0.7378 - val_loss: 1.1093 - val_accuracy: 0.6319
# Epoch 24/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6501 - accuracy: 0.7604 - val_loss: 1.1687 - val_accuracy: 0.6111
# Epoch 25/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.5997 - accuracy: 0.7778 - val_loss: 1.1639 - val_accuracy: 0.6181
# Epoch 26/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.5771 - accuracy: 0.7951 - val_loss: 1.0893 - val_accuracy: 0.6250
# Epoch 27/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4968 - accuracy: 0.8299 - val_loss: 1.1471 - val_accuracy: 0.6389
# Epoch 28/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.5015 - accuracy: 0.8177 - val_loss: 1.1715 - val_accuracy: 0.6458
# Epoch 29/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3917 - accuracy: 0.8576 - val_loss: 1.1197 - val_accuracy: 0.6736
# Epoch 30/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4422 - accuracy: 0.8333 - val_loss: 1.2385 - val_accuracy: 0.6736
# Epoch 31/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4112 - accuracy: 0.8681 - val_loss: 1.1668 - val_accuracy: 0.6875
# Epoch 32/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4213 - accuracy: 0.8385 - val_loss: 1.1302 - val_accuracy: 0.6806
# Epoch 33/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4636 - accuracy: 0.8316 - val_loss: 1.0567 - val_accuracy: 0.7014
# Epoch 34/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3924 - accuracy: 0.8611 - val_loss: 1.1320 - val_accuracy: 0.6667
# Epoch 35/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4441 - accuracy: 0.8194 - val_loss: 1.0487 - val_accuracy: 0.6944
# Epoch 36/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4254 - accuracy: 0.8542 - val_loss: 1.1552 - val_accuracy: 0.6597
# Epoch 37/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4176 - accuracy: 0.8333 - val_loss: 1.0472 - val_accuracy: 0.6806
# Epoch 38/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3569 - accuracy: 0.8681 - val_loss: 1.2762 - val_accuracy: 0.6736
# Epoch 39/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3723 - accuracy: 0.8490 - val_loss: 1.1403 - val_accuracy: 0.6597
# Epoch 40/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3508 - accuracy: 0.8733 - val_loss: 1.1904 - val_accuracy: 0.7014
# Epoch 41/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3253 - accuracy: 0.8958 - val_loss: 1.1511 - val_accuracy: 0.6667
# Epoch 42/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3369 - accuracy: 0.8941 - val_loss: 1.1343 - val_accuracy: 0.6806
# Epoch 43/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3463 - accuracy: 0.8802 - val_loss: 1.2404 - val_accuracy: 0.6736
# Epoch 44/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3337 - accuracy: 0.8819 - val_loss: 1.2035 - val_accuracy: 0.6806
# Epoch 45/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3939 - accuracy: 0.8420 - val_loss: 1.2663 - val_accuracy: 0.6736
# Epoch 46/100
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2884 - accuracy: 0.8993 - val_loss: 1.3240 - val_accuracy: 0.6944
# Epoch 47/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3337 - accuracy: 0.8733 - val_loss: 1.1417 - val_accuracy: 0.6806
# Epoch 48/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3185 - accuracy: 0.8854 - val_loss: 1.2767 - val_accuracy: 0.6944
# Epoch 49/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3401 - accuracy: 0.8750 - val_loss: 1.2553 - val_accuracy: 0.6944
# Epoch 50/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2881 - accuracy: 0.8958 - val_loss: 1.1974 - val_accuracy: 0.7014
# Epoch 51/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3100 - accuracy: 0.8889 - val_loss: 1.2222 - val_accuracy: 0.6806
# Epoch 52/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2932 - accuracy: 0.8941 - val_loss: 1.2241 - val_accuracy: 0.7014
# Epoch 53/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3094 - accuracy: 0.8906 - val_loss: 1.2353 - val_accuracy: 0.7153
# Epoch 54/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2596 - accuracy: 0.9028 - val_loss: 1.2006 - val_accuracy: 0.7153
# Epoch 55/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2594 - accuracy: 0.9010 - val_loss: 1.2489 - val_accuracy: 0.7083
# Epoch 56/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3024 - accuracy: 0.8924 - val_loss: 1.4146 - val_accuracy: 0.6944
# Epoch 57/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2354 - accuracy: 0.9149 - val_loss: 1.1799 - val_accuracy: 0.7014
# Epoch 58/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2646 - accuracy: 0.8976 - val_loss: 1.2036 - val_accuracy: 0.6736
# Epoch 59/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2612 - accuracy: 0.9115 - val_loss: 1.2833 - val_accuracy: 0.6736
# Epoch 60/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2484 - accuracy: 0.9132 - val_loss: 1.3325 - val_accuracy: 0.6736
# Epoch 61/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2625 - accuracy: 0.9167 - val_loss: 1.3055 - val_accuracy: 0.6875
# Epoch 62/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2714 - accuracy: 0.9028 - val_loss: 1.3130 - val_accuracy: 0.6667
# Epoch 63/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2554 - accuracy: 0.9062 - val_loss: 1.2481 - val_accuracy: 0.7083
# Epoch 64/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2500 - accuracy: 0.9045 - val_loss: 1.2403 - val_accuracy: 0.7083
# Epoch 65/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2787 - accuracy: 0.9045 - val_loss: 1.2618 - val_accuracy: 0.6806
# Epoch 66/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2345 - accuracy: 0.9219 - val_loss: 1.2341 - val_accuracy: 0.7292
# Epoch 67/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2474 - accuracy: 0.9132 - val_loss: 1.3061 - val_accuracy: 0.7153
# Epoch 68/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2573 - accuracy: 0.9149 - val_loss: 1.1932 - val_accuracy: 0.7500
# Epoch 69/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2292 - accuracy: 0.9288 - val_loss: 1.1635 - val_accuracy: 0.7153
# Epoch 70/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2387 - accuracy: 0.9167 - val_loss: 1.2409 - val_accuracy: 0.7153
# Epoch 71/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2210 - accuracy: 0.9340 - val_loss: 1.2390 - val_accuracy: 0.7292
# Epoch 72/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2170 - accuracy: 0.9323 - val_loss: 1.3742 - val_accuracy: 0.7014
# Epoch 73/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2119 - accuracy: 0.9167 - val_loss: 1.3256 - val_accuracy: 0.7083
# Epoch 74/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3140 - accuracy: 0.8941 - val_loss: 1.2465 - val_accuracy: 0.6875
# Epoch 75/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.1747 - accuracy: 0.9375 - val_loss: 1.2003 - val_accuracy: 0.6806
# Epoch 76/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2180 - accuracy: 0.9236 - val_loss: 1.2085 - val_accuracy: 0.6944
# Epoch 77/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2033 - accuracy: 0.9288 - val_loss: 1.3352 - val_accuracy: 0.6944
# Epoch 78/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2387 - accuracy: 0.9115 - val_loss: 1.3592 - val_accuracy: 0.7222
# Epoch 79/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.1940 - accuracy: 0.9271 - val_loss: 1.3238 - val_accuracy: 0.6875
# Epoch 80/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2109 - accuracy: 0.9201 - val_loss: 1.4856 - val_accuracy: 0.6736
# Epoch 81/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1811 - accuracy: 0.9427 - val_loss: 1.4609 - val_accuracy: 0.6875
# Epoch 82/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2137 - accuracy: 0.9253 - val_loss: 1.3179 - val_accuracy: 0.6944
# Epoch 83/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2089 - accuracy: 0.9184 - val_loss: 1.4867 - val_accuracy: 0.6944
# Epoch 84/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1872 - accuracy: 0.9236 - val_loss: 1.4570 - val_accuracy: 0.6736
# Epoch 85/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1823 - accuracy: 0.9392 - val_loss: 1.2964 - val_accuracy: 0.6944
# Epoch 86/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1796 - accuracy: 0.9358 - val_loss: 1.3122 - val_accuracy: 0.7292
# Epoch 87/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2105 - accuracy: 0.9358 - val_loss: 1.4019 - val_accuracy: 0.7361
# Epoch 88/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.1818 - accuracy: 0.9375 - val_loss: 1.5600 - val_accuracy: 0.6944
# Epoch 89/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.1787 - accuracy: 0.9340 - val_loss: 1.3943 - val_accuracy: 0.6875
# Epoch 90/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2136 - accuracy: 0.9271 - val_loss: 1.4642 - val_accuracy: 0.7083
# Epoch 91/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.1816 - accuracy: 0.9358 - val_loss: 1.3090 - val_accuracy: 0.7361
# Epoch 92/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1669 - accuracy: 0.9427 - val_loss: 1.2480 - val_accuracy: 0.7083
# Epoch 93/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2065 - accuracy: 0.9271 - val_loss: 1.2971 - val_accuracy: 0.7292
# Epoch 94/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2405 - accuracy: 0.9132 - val_loss: 1.5762 - val_accuracy: 0.7153
# Epoch 95/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1823 - accuracy: 0.9358 - val_loss: 1.4036 - val_accuracy: 0.7500
# Epoch 96/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1981 - accuracy: 0.9184 - val_loss: 1.3734 - val_accuracy: 0.7569
# Epoch 97/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.1905 - accuracy: 0.9340 - val_loss: 1.5101 - val_accuracy: 0.7014
# Epoch 98/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2151 - accuracy: 0.9444 - val_loss: 1.3965 - val_accuracy: 0.7083
# Epoch 99/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.1924 - accuracy: 0.9306 - val_loss: 1.3400 - val_accuracy: 0.7153
# Epoch 100/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1877 - accuracy: 0.9358 - val_loss: 1.3165 - val_accuracy: 0.7222
# 5/5 [==============================] - 0s 22ms/step - loss: 1.3165 - accuracy: 0.7222
# Test loss: 1.316532015800476
# Test accuracy: 0.7222222089767456

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()
