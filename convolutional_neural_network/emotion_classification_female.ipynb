# %% [markdown]
# # Convolutional Neural Network Using Mel Spectrogram Classifying Gender

# %%
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Flatten, Conv2D, MaxPooling2D, LeakyReLU
from keras.optimizers import Adam
from keras.utils import to_categorical
from keras.regularizers import l2
from sklearn.preprocessing import MinMaxScaler
import librosa
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %matplotlib inline

# %%
audio_data = np.load("../data/audio_data.npy")
labels = np.load("../data/wav_labels.npy")

# labels: modality-vocal channel-emotion-emotional intensity-statement-repetition-actor
# emotions: 01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised
# odd number actors = male, even = female

# 1440 files: 24 speakers, 60 recordings per speaker
audio_data = audio_data.reshape(1440, 9480)

features = []

for i in range(1440):
    
    if (labels[i][6]%2 == 0):
        label = "Female"
    else:
        label = "Male"

    if (labels[i][2] == 1):
        em = 0
    elif (labels[i][2] == 2):
        em = 1
    elif (labels[i][2] == 3):
        em = 2
    elif (labels[i][2] == 4):
        em = 3
    elif (labels[i][2] == 5):
        em = 4
    elif (labels[i][2] == 6):
        em = 5
    elif (labels[i][2] == 7):
        em = 6
    elif (labels[i][2] == 8):
        em = 7
    
    features.append([audio_data[i], label, em])
    
feature_df = pd.DataFrame(features, columns = ["mfcc", "gender", "emotion"])

feature_df.head()
# Out:
#                                                 mfcc gender  emotion
# 0  [-855.3770751953125, -855.3770751953125, -855....   Male        0
# 1  [-850.3917236328125, -850.435791015625, -850.4...   Male        0
# 2  [-849.78369140625, -848.8447265625, -848.56610...   Male        0
# 3  [-842.9385375976562, -843.2474975585938, -850....   Male        0
# 4  [-911.1758422851562, -910.4053344726562, -905....   Male        1

# %%
#split data - males vs females
mal = feature_df.loc[feature_df['gender'] == "Male"]
fem = feature_df.loc[feature_df['gender'] == "Female"]

## ===== Females ===== ##
X_females_unscaled = np.array(fem.mfcc.tolist())
y_females = np.array(fem.emotion.tolist())

scaler = MinMaxScaler(feature_range=(-1,1))
scaler.fit(X_females_unscaled)
X_females_scaled = scaler.transform(X_females_unscaled)

#20-80 train-test split
X_train_females, X_test_females, y_train_females, y_test_females = train_test_split(X_females_scaled, y_females, test_size=0.20, random_state=0)

# %%
# Reshape for CNN input
X_train_females = np.array([x.reshape( (20, 474, 1) ) for x in X_train_females])
X_test_females = np.array([x.reshape( (20, 474, 1) ) for x in X_test_females])

# One-Hot encoding for classes
y_train_females = np.array(to_categorical(y_train_females, 8))
y_test_females = np.array(to_categorical(y_test_females, 8))

# %%
model = Sequential()

model.add(Conv2D(64, (5,5), input_shape=X_test_females.shape[1:], kernel_regularizer=l2(l=0.01)))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(24, (4,4)))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(rate=0.1))

model.add(Conv2D(24, (3,3)))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(rate=0.2))

model.add(Conv2D(80, (2,2)))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(rate=0.5))

model.add(Flatten())
model.add(Dense(64))
model.add(LeakyReLU(alpha=0.1))

model.add(Dropout(rate=0.5))
model.add(Dense(8))
model.add(Activation('softmax'))

# %%
opt = Adam(learning_rate=0.001)

model.compile(
	optimizer="Adam",
	loss="categorical_crossentropy",
	metrics=['accuracy']
)

history = model.fit(
	x=X_train_females,
	y=y_train_females,
    epochs=150,
    batch_size=75,
    validation_data=(X_test_females, y_test_females)
)

y_pred = model.predict(X_test_females)

score = model.evaluate(
	x=X_test_females,
	y=y_test_females)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/150
# 8/8 [==============================] - 6s 689ms/step - loss: 2.1030 - accuracy: 0.1562 - val_loss: 2.0866 - val_accuracy: 0.1111
# Epoch 2/150
# 8/8 [==============================] - 0s 37ms/step - loss: 2.0618 - accuracy: 0.1927 - val_loss: 2.0609 - val_accuracy: 0.1944
# Epoch 3/150
# 8/8 [==============================] - 0s 35ms/step - loss: 1.9843 - accuracy: 0.2188 - val_loss: 1.8754 - val_accuracy: 0.3194
# Epoch 4/150
# 8/8 [==============================] - 0s 35ms/step - loss: 1.8250 - accuracy: 0.3056 - val_loss: 1.7086 - val_accuracy: 0.3750
# Epoch 5/150
# 8/8 [==============================] - 0s 33ms/step - loss: 1.6432 - accuracy: 0.3698 - val_loss: 1.5949 - val_accuracy: 0.4097
# Epoch 6/150
# 8/8 [==============================] - 0s 34ms/step - loss: 1.5229 - accuracy: 0.4062 - val_loss: 1.5325 - val_accuracy: 0.4167
# Epoch 7/150
# 8/8 [==============================] - 0s 34ms/step - loss: 1.3752 - accuracy: 0.4948 - val_loss: 1.5210 - val_accuracy: 0.4306
# Epoch 8/150
# 8/8 [==============================] - 0s 34ms/step - loss: 1.2508 - accuracy: 0.5486 - val_loss: 1.4434 - val_accuracy: 0.4861
# Epoch 9/150
# 8/8 [==============================] - 0s 33ms/step - loss: 1.1106 - accuracy: 0.6215 - val_loss: 1.4016 - val_accuracy: 0.4861
# Epoch 10/150
# 8/8 [==============================] - 0s 36ms/step - loss: 1.0025 - accuracy: 0.6424 - val_loss: 1.3083 - val_accuracy: 0.5069
# Epoch 11/150
# 8/8 [==============================] - 0s 35ms/step - loss: 0.8251 - accuracy: 0.7170 - val_loss: 1.3491 - val_accuracy: 0.5278
# Epoch 12/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.7384 - accuracy: 0.7326 - val_loss: 1.3778 - val_accuracy: 0.5000
# Epoch 13/150
# 8/8 [==============================] - 0s 36ms/step - loss: 0.7567 - accuracy: 0.7274 - val_loss: 1.2935 - val_accuracy: 0.5139
# Epoch 14/150
# 8/8 [==============================] - 0s 41ms/step - loss: 0.6755 - accuracy: 0.7656 - val_loss: 1.3498 - val_accuracy: 0.5139
# Epoch 15/150
# 8/8 [==============================] - 0s 37ms/step - loss: 0.5695 - accuracy: 0.8177 - val_loss: 1.3954 - val_accuracy: 0.5625
# Epoch 16/150
# 8/8 [==============================] - 0s 36ms/step - loss: 0.5076 - accuracy: 0.8177 - val_loss: 1.3620 - val_accuracy: 0.5764
# Epoch 17/150
# 8/8 [==============================] - 0s 38ms/step - loss: 0.5058 - accuracy: 0.8247 - val_loss: 1.2868 - val_accuracy: 0.5694
# Epoch 18/150
# 8/8 [==============================] - 0s 36ms/step - loss: 0.5012 - accuracy: 0.8160 - val_loss: 1.2944 - val_accuracy: 0.5694
# Epoch 19/150
# 8/8 [==============================] - 0s 38ms/step - loss: 0.4254 - accuracy: 0.8646 - val_loss: 1.3400 - val_accuracy: 0.5625
# Epoch 20/150
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3929 - accuracy: 0.8646 - val_loss: 1.4228 - val_accuracy: 0.5972
# Epoch 21/150
# 8/8 [==============================] - 0s 36ms/step - loss: 0.3537 - accuracy: 0.8750 - val_loss: 1.4426 - val_accuracy: 0.5625
# Epoch 22/150
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3141 - accuracy: 0.8958 - val_loss: 1.4587 - val_accuracy: 0.5903
# Epoch 23/150
# 8/8 [==============================] - 0s 36ms/step - loss: 0.2545 - accuracy: 0.9115 - val_loss: 1.4366 - val_accuracy: 0.6181
# Epoch 24/150
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2448 - accuracy: 0.9149 - val_loss: 1.4095 - val_accuracy: 0.6389
# Epoch 25/150
# 8/8 [==============================] - 0s 36ms/step - loss: 0.2155 - accuracy: 0.9271 - val_loss: 1.4921 - val_accuracy: 0.6181
# Epoch 26/150
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2151 - accuracy: 0.9358 - val_loss: 1.3243 - val_accuracy: 0.6250
# Epoch 27/150
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2229 - accuracy: 0.9219 - val_loss: 1.3494 - val_accuracy: 0.6250
# Epoch 28/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1835 - accuracy: 0.9444 - val_loss: 1.4318 - val_accuracy: 0.6458
# Epoch 29/150
# 8/8 [==============================] - 0s 36ms/step - loss: 0.2117 - accuracy: 0.9375 - val_loss: 1.5578 - val_accuracy: 0.6806
# Epoch 30/150
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2133 - accuracy: 0.9323 - val_loss: 1.4763 - val_accuracy: 0.5903
# Epoch 31/150
# 8/8 [==============================] - 0s 35ms/step - loss: 0.1835 - accuracy: 0.9497 - val_loss: 1.4851 - val_accuracy: 0.6389
# Epoch 32/150
# 8/8 [==============================] - 0s 35ms/step - loss: 0.1688 - accuracy: 0.9444 - val_loss: 1.6012 - val_accuracy: 0.6181
# Epoch 33/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1878 - accuracy: 0.9427 - val_loss: 1.5357 - val_accuracy: 0.6319
# Epoch 34/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1517 - accuracy: 0.9583 - val_loss: 1.6036 - val_accuracy: 0.6458
# Epoch 35/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1848 - accuracy: 0.9410 - val_loss: 1.8207 - val_accuracy: 0.6458
# Epoch 36/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1527 - accuracy: 0.9583 - val_loss: 1.4696 - val_accuracy: 0.6667
# Epoch 37/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1636 - accuracy: 0.9410 - val_loss: 1.4999 - val_accuracy: 0.6181
# Epoch 38/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1362 - accuracy: 0.9653 - val_loss: 1.5272 - val_accuracy: 0.6597
# Epoch 39/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1242 - accuracy: 0.9635 - val_loss: 1.5818 - val_accuracy: 0.6389
# Epoch 40/150
# 8/8 [==============================] - 0s 36ms/step - loss: 0.1149 - accuracy: 0.9583 - val_loss: 1.6861 - val_accuracy: 0.6250
# Epoch 41/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1256 - accuracy: 0.9635 - val_loss: 1.6439 - val_accuracy: 0.6875
# Epoch 42/150
# 8/8 [==============================] - 0s 36ms/step - loss: 0.1265 - accuracy: 0.9653 - val_loss: 1.6515 - val_accuracy: 0.5903
# Epoch 43/150
# 8/8 [==============================] - 0s 40ms/step - loss: 0.1375 - accuracy: 0.9566 - val_loss: 1.6222 - val_accuracy: 0.6250
# Epoch 44/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1326 - accuracy: 0.9618 - val_loss: 1.6916 - val_accuracy: 0.6389
# Epoch 45/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0983 - accuracy: 0.9688 - val_loss: 1.7728 - val_accuracy: 0.6111
# Epoch 46/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1250 - accuracy: 0.9635 - val_loss: 1.8881 - val_accuracy: 0.6250
# Epoch 47/150
# 8/8 [==============================] - 0s 35ms/step - loss: 0.1167 - accuracy: 0.9792 - val_loss: 1.7098 - val_accuracy: 0.6458
# Epoch 48/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1010 - accuracy: 0.9722 - val_loss: 1.6484 - val_accuracy: 0.6319
# Epoch 49/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1138 - accuracy: 0.9670 - val_loss: 1.5625 - val_accuracy: 0.6736
# Epoch 50/150
# 8/8 [==============================] - 0s 38ms/step - loss: 0.1271 - accuracy: 0.9635 - val_loss: 1.6969 - val_accuracy: 0.6389
# Epoch 51/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1083 - accuracy: 0.9688 - val_loss: 1.6250 - val_accuracy: 0.6319
# Epoch 52/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1089 - accuracy: 0.9688 - val_loss: 1.5882 - val_accuracy: 0.6319
# Epoch 53/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1157 - accuracy: 0.9635 - val_loss: 1.6389 - val_accuracy: 0.6458
# Epoch 54/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0827 - accuracy: 0.9792 - val_loss: 1.7609 - val_accuracy: 0.6319
# Epoch 55/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0961 - accuracy: 0.9722 - val_loss: 1.7639 - val_accuracy: 0.6111
# Epoch 56/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0983 - accuracy: 0.9705 - val_loss: 1.6345 - val_accuracy: 0.6667
# Epoch 57/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1098 - accuracy: 0.9722 - val_loss: 1.8401 - val_accuracy: 0.6667
# Epoch 58/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1028 - accuracy: 0.9670 - val_loss: 2.0391 - val_accuracy: 0.6250
# Epoch 59/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0749 - accuracy: 0.9861 - val_loss: 2.0903 - val_accuracy: 0.6250
# Epoch 60/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0757 - accuracy: 0.9757 - val_loss: 2.0273 - val_accuracy: 0.6458
# Epoch 61/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0763 - accuracy: 0.9792 - val_loss: 1.9797 - val_accuracy: 0.6181
# Epoch 62/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1026 - accuracy: 0.9792 - val_loss: 1.8847 - val_accuracy: 0.6389
# Epoch 63/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0748 - accuracy: 0.9792 - val_loss: 2.0256 - val_accuracy: 0.6111
# Epoch 64/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0618 - accuracy: 0.9861 - val_loss: 2.1536 - val_accuracy: 0.6181
# Epoch 65/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0861 - accuracy: 0.9740 - val_loss: 1.9852 - val_accuracy: 0.6319
# Epoch 66/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0510 - accuracy: 0.9896 - val_loss: 1.9604 - val_accuracy: 0.6181
# Epoch 67/150
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0758 - accuracy: 0.9792 - val_loss: 1.9230 - val_accuracy: 0.6181
# Epoch 68/150
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0633 - accuracy: 0.9896 - val_loss: 1.9679 - val_accuracy: 0.6528
# Epoch 69/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0758 - accuracy: 0.9809 - val_loss: 2.1175 - val_accuracy: 0.6389
# Epoch 70/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0564 - accuracy: 0.9861 - val_loss: 2.1926 - val_accuracy: 0.6806
# Epoch 71/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0771 - accuracy: 0.9809 - val_loss: 2.1434 - val_accuracy: 0.6389
# Epoch 72/150
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0535 - accuracy: 0.9896 - val_loss: 2.2765 - val_accuracy: 0.6319
# Epoch 73/150
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0622 - accuracy: 0.9844 - val_loss: 2.1513 - val_accuracy: 0.6111
# Epoch 74/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0709 - accuracy: 0.9896 - val_loss: 1.9602 - val_accuracy: 0.6528
# Epoch 75/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0904 - accuracy: 0.9844 - val_loss: 1.7921 - val_accuracy: 0.6389
# Epoch 76/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0626 - accuracy: 0.9861 - val_loss: 1.9791 - val_accuracy: 0.6458
# Epoch 77/150
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0660 - accuracy: 0.9792 - val_loss: 2.0504 - val_accuracy: 0.6250
# Epoch 78/150
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0628 - accuracy: 0.9844 - val_loss: 2.1643 - val_accuracy: 0.6250
# Epoch 79/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0643 - accuracy: 0.9878 - val_loss: 1.9850 - val_accuracy: 0.6319
# Epoch 80/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0624 - accuracy: 0.9861 - val_loss: 1.9357 - val_accuracy: 0.6736
# Epoch 81/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0789 - accuracy: 0.9809 - val_loss: 1.9235 - val_accuracy: 0.6528
# Epoch 82/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0879 - accuracy: 0.9722 - val_loss: 1.9874 - val_accuracy: 0.6181
# Epoch 83/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0666 - accuracy: 0.9757 - val_loss: 2.1446 - val_accuracy: 0.6042
# Epoch 84/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0680 - accuracy: 0.9826 - val_loss: 2.1202 - val_accuracy: 0.6458
# Epoch 85/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0771 - accuracy: 0.9792 - val_loss: 1.9962 - val_accuracy: 0.6111
# Epoch 86/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0690 - accuracy: 0.9792 - val_loss: 1.8872 - val_accuracy: 0.6319
# Epoch 87/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0638 - accuracy: 0.9861 - val_loss: 1.7371 - val_accuracy: 0.6736
# Epoch 88/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0680 - accuracy: 0.9826 - val_loss: 1.8869 - val_accuracy: 0.6528
# Epoch 89/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0508 - accuracy: 0.9913 - val_loss: 1.9135 - val_accuracy: 0.6528
# Epoch 90/150
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0542 - accuracy: 0.9878 - val_loss: 2.0082 - val_accuracy: 0.6528
# Epoch 91/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0665 - accuracy: 0.9878 - val_loss: 2.0302 - val_accuracy: 0.6319
# Epoch 92/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0518 - accuracy: 0.9878 - val_loss: 1.8024 - val_accuracy: 0.6736
# Epoch 93/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0421 - accuracy: 0.9878 - val_loss: 1.7926 - val_accuracy: 0.6806
# Epoch 94/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0421 - accuracy: 0.9948 - val_loss: 1.9682 - val_accuracy: 0.6667
# Epoch 95/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0514 - accuracy: 0.9878 - val_loss: 2.2040 - val_accuracy: 0.6042
# Epoch 96/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0596 - accuracy: 0.9878 - val_loss: 2.0535 - val_accuracy: 0.6319
# Epoch 97/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0465 - accuracy: 0.9913 - val_loss: 2.0263 - val_accuracy: 0.6319
# Epoch 98/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0467 - accuracy: 0.9861 - val_loss: 2.2761 - val_accuracy: 0.6319
# Epoch 99/150
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0556 - accuracy: 0.9878 - val_loss: 2.2000 - val_accuracy: 0.6389
# Epoch 100/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0584 - accuracy: 0.9844 - val_loss: 2.2277 - val_accuracy: 0.6319
# Epoch 101/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0548 - accuracy: 0.9896 - val_loss: 2.2574 - val_accuracy: 0.6667
# Epoch 102/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0646 - accuracy: 0.9792 - val_loss: 2.0464 - val_accuracy: 0.6528
# Epoch 103/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0563 - accuracy: 0.9826 - val_loss: 2.0889 - val_accuracy: 0.6389
# Epoch 104/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0531 - accuracy: 0.9896 - val_loss: 2.0036 - val_accuracy: 0.6389
# Epoch 105/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0490 - accuracy: 0.9896 - val_loss: 1.8854 - val_accuracy: 0.6736
# Epoch 106/150
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0602 - accuracy: 0.9861 - val_loss: 1.9728 - val_accuracy: 0.6528
# Epoch 107/150
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0956 - accuracy: 0.9670 - val_loss: 1.8963 - val_accuracy: 0.6667
# Epoch 108/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0612 - accuracy: 0.9861 - val_loss: 1.9880 - val_accuracy: 0.6250
# Epoch 109/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0849 - accuracy: 0.9809 - val_loss: 2.2650 - val_accuracy: 0.5903
# Epoch 110/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0974 - accuracy: 0.9705 - val_loss: 2.0910 - val_accuracy: 0.6250
# Epoch 111/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0814 - accuracy: 0.9757 - val_loss: 2.0352 - val_accuracy: 0.6319
# Epoch 112/150
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0775 - accuracy: 0.9774 - val_loss: 2.2292 - val_accuracy: 0.5903
# Epoch 113/150
# 8/8 [==============================] - 0s 41ms/step - loss: 0.0549 - accuracy: 0.9844 - val_loss: 2.0030 - val_accuracy: 0.6736
# Epoch 114/150
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0730 - accuracy: 0.9740 - val_loss: 1.9511 - val_accuracy: 0.6458
# Epoch 115/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0701 - accuracy: 0.9792 - val_loss: 2.1166 - val_accuracy: 0.6181
# Epoch 116/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0613 - accuracy: 0.9861 - val_loss: 2.2496 - val_accuracy: 0.6458
# Epoch 117/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0436 - accuracy: 0.9931 - val_loss: 2.3086 - val_accuracy: 0.6389
# Epoch 118/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0398 - accuracy: 0.9861 - val_loss: 2.4255 - val_accuracy: 0.6042
# Epoch 119/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0410 - accuracy: 0.9913 - val_loss: 2.2927 - val_accuracy: 0.6458
# Epoch 120/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0459 - accuracy: 0.9861 - val_loss: 2.3496 - val_accuracy: 0.6458
# Epoch 121/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0458 - accuracy: 0.9913 - val_loss: 2.5184 - val_accuracy: 0.6389
# Epoch 122/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0792 - accuracy: 0.9705 - val_loss: 2.3488 - val_accuracy: 0.6319
# Epoch 123/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0802 - accuracy: 0.9844 - val_loss: 2.2182 - val_accuracy: 0.6597
# Epoch 124/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0397 - accuracy: 0.9931 - val_loss: 2.4815 - val_accuracy: 0.6250
# Epoch 125/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0687 - accuracy: 0.9774 - val_loss: 2.4830 - val_accuracy: 0.6111
# Epoch 126/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0377 - accuracy: 0.9948 - val_loss: 2.2794 - val_accuracy: 0.6389
# Epoch 127/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0604 - accuracy: 0.9792 - val_loss: 2.0177 - val_accuracy: 0.6736
# Epoch 128/150
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0341 - accuracy: 0.9913 - val_loss: 2.0088 - val_accuracy: 0.6736
# Epoch 129/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0414 - accuracy: 0.9878 - val_loss: 2.0352 - val_accuracy: 0.6875
# Epoch 130/150
# 8/8 [==============================] - 0s 40ms/step - loss: 0.0537 - accuracy: 0.9896 - val_loss: 1.9593 - val_accuracy: 0.7014
# Epoch 131/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0541 - accuracy: 0.9878 - val_loss: 2.4324 - val_accuracy: 0.6319
# Epoch 132/150
# 8/8 [==============================] - 0s 36ms/step - loss: 0.0598 - accuracy: 0.9878 - val_loss: 2.2085 - val_accuracy: 0.6667
# Epoch 133/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0558 - accuracy: 0.9861 - val_loss: 2.0770 - val_accuracy: 0.6806
# Epoch 134/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0480 - accuracy: 0.9861 - val_loss: 1.8276 - val_accuracy: 0.6875
# Epoch 135/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0424 - accuracy: 0.9861 - val_loss: 1.9663 - val_accuracy: 0.6806
# Epoch 136/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0294 - accuracy: 0.9965 - val_loss: 2.0614 - val_accuracy: 0.6736
# Epoch 137/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0364 - accuracy: 0.9896 - val_loss: 2.1004 - val_accuracy: 0.6458
# Epoch 138/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0371 - accuracy: 0.9913 - val_loss: 2.1078 - val_accuracy: 0.6736
# Epoch 139/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0382 - accuracy: 0.9913 - val_loss: 2.2738 - val_accuracy: 0.6597
# Epoch 140/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0462 - accuracy: 0.9931 - val_loss: 2.4423 - val_accuracy: 0.6319
# Epoch 141/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0635 - accuracy: 0.9809 - val_loss: 2.1105 - val_accuracy: 0.6597
# Epoch 142/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0306 - accuracy: 0.9948 - val_loss: 2.0291 - val_accuracy: 0.6736
# Epoch 143/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0429 - accuracy: 0.9878 - val_loss: 2.0413 - val_accuracy: 0.6458
# Epoch 144/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0457 - accuracy: 0.9844 - val_loss: 2.1111 - val_accuracy: 0.6389
# Epoch 145/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0424 - accuracy: 0.9896 - val_loss: 2.1082 - val_accuracy: 0.6667
# Epoch 146/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0326 - accuracy: 0.9931 - val_loss: 2.1701 - val_accuracy: 0.6181
# Epoch 147/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0380 - accuracy: 0.9931 - val_loss: 2.2250 - val_accuracy: 0.6250
# Epoch 148/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0397 - accuracy: 0.9878 - val_loss: 2.2167 - val_accuracy: 0.6250
# Epoch 149/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0435 - accuracy: 0.9948 - val_loss: 2.1447 - val_accuracy: 0.6736
# Epoch 150/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0347 - accuracy: 0.9913 - val_loss: 2.1421 - val_accuracy: 0.6736
# 5/5 [==============================] - 0s 6ms/step - loss: 2.1421 - accuracy: 0.6736
# Test loss: 2.14213228225708
# Test accuracy: 0.6736111044883728

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Female Data Training and Validation Accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Female Data Training and Validation Loss')
plt.legend()
plt.show()

# %%
#Algorithm Evaluation
cm = confusion_matrix(y_test_females.argmax(axis=1), y_pred.argmax(axis=1))
print("CNN Female Emotion Classification")
df = pd.DataFrame(cm, columns=[y_females[0], y_females[4], y_females[12], y_females[20], y_females[28], y_females[36], y_females[44], y_females[52] ])
print(df)

#figure for confusion matrix
cm = confusion_matrix(y_test_females.argmax(axis=1), y_pred.argmax(axis=1))
plt.figure(figsize=(10,4))
plt.imshow(cm)
plt.title("CNN Female Emotion Classification")
plt.show()

#precision function
def precision(confmatrix):
    # precision = tp/(tp+fp)
    tp = np.diag(confmatrix)
    fp = np.sum(confmatrix, axis=0) - tp
    precision = np.mean(tp/(tp+fp))
    return precision

prec = precision(cm)
# Out:
# CNN Female Emotion Classification
#    0   1   2  3   4   5  6   7
# 0  8   2   1  2   0   0  0   0
# 1  3  17   0  1   0   0  0   1
# 2  0   1  15  0   0   0  1   2
# 3  1   6   0  8   0   2  0   1
# 4  0   0   1  0  11   0  0   3
# 5  0   1   3  2   0  11  0   2
# 6  0   0   0  3   4   0  9   0
# 7  0   0   2  0   0   1  1  18
