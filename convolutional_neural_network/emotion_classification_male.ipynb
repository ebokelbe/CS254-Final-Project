# %% [markdown]
# # Convolutional Neural Network Using Mel Spectrogram Classifying Gender

# %%
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Flatten, Conv2D, MaxPooling2D, LeakyReLU
from keras.optimizers import Adam
from keras.utils import to_categorical
from keras.regularizers import l2
from sklearn.preprocessing import MinMaxScaler
import librosa
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %matplotlib inline

# %%
audio_data = np.load("../data/audio_data.npy")
labels = np.load("../data/wav_labels.npy")

# labels: modality-vocal channel-emotion-emotional intensity-statement-repetition-actor
# emotions: 01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised
# odd number actors = male, even = female

# 1440 files: 24 speakers, 60 recordings per speaker
audio_data = audio_data.reshape(1440, 9480)

features = []

for i in range(1440):
    
    if (labels[i][6]%2 == 0):
        label = "Female"
    else:
        label = "Male"

    if (labels[i][2] == 1):
        em = 0
    elif (labels[i][2] == 2):
        em = 1
    elif (labels[i][2] == 3):
        em = 2
    elif (labels[i][2] == 4):
        em = 3
    elif (labels[i][2] == 5):
        em = 4
    elif (labels[i][2] == 6):
        em = 5
    elif (labels[i][2] == 7):
        em = 6
    elif (labels[i][2] == 8):
        em = 7
    
    features.append([audio_data[i], label, em])
    
feature_df = pd.DataFrame(features, columns = ["mfcc", "gender", "emotion"])

feature_df.head()
# Out:
#                                                 mfcc gender  emotion
# 0  [-855.3770751953125, -855.3770751953125, -855....   Male        0
# 1  [-850.3917236328125, -850.435791015625, -850.4...   Male        0
# 2  [-849.78369140625, -848.8447265625, -848.56610...   Male        0
# 3  [-842.9385375976562, -843.2474975585938, -850....   Male        0
# 4  [-911.1758422851562, -910.4053344726562, -905....   Male        1

# %%
#split data - males vs females
mal = feature_df.loc[feature_df['gender'] == "Male"]
fem = feature_df.loc[feature_df['gender'] == "Female"]

## ===== Females ===== ##
X_males_unscaled = np.array(mal.mfcc.tolist())
y_males = np.array(mal.emotion.tolist())

scaler = MinMaxScaler(feature_range=(-1,1))
scaler.fit(X_males_unscaled)
X_males_scaled = scaler.transform(X_males_unscaled)

#20-80 train-test split
X_train_males, X_test_males, y_train_males, y_test_males = train_test_split(X_males_scaled, y_males, test_size=0.20, random_state=0)

# %%
# Reshape for CNN input
X_train_males = np.array([x.reshape( (20, 474, 1) ) for x in X_train_males])
X_test_males = np.array([x.reshape( (20, 474, 1) ) for x in X_test_males])

# One-Hot encoding for classes
y_train_males = np.array(to_categorical(y_train_males, 8))
y_test_males = np.array(to_categorical(y_test_males, 8))

# %%
model = Sequential()

model.add(Conv2D(64, (5,5), input_shape=X_test_males.shape[1:], kernel_regularizer=l2(l=0.01)))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(24, (4,4)))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(rate=0.1))

model.add(Conv2D(24, (3,3)))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(rate=0.2))

model.add(Conv2D(80, (2,2)))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(rate=0.5))

model.add(Flatten())
model.add(Dense(64))
model.add(LeakyReLU(alpha=0.1))

model.add(Dropout(rate=0.5))
model.add(Dense(8))
model.add(Activation('softmax'))

# %%
opt = Adam(learning_rate=0.001)

model.compile(
	optimizer=opt,
	loss="categorical_crossentropy",
	metrics=['accuracy']
)

history = model.fit(
	x=X_train_males,
	y=y_train_males,
    epochs=150,
    batch_size=75,
    validation_data=(X_test_males, y_test_males)
)

y_pred = model.predict(X_test_males)

score = model.evaluate(
	x=X_test_males,
	y=y_test_males)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/150
# 8/8 [==============================] - 1s 109ms/step - loss: 2.0956 - accuracy: 0.1580 - val_loss: 2.0776 - val_accuracy: 0.2153
# Epoch 2/150
# 8/8 [==============================] - 0s 33ms/step - loss: 2.0697 - accuracy: 0.1406 - val_loss: 2.0230 - val_accuracy: 0.2361
# Epoch 3/150
# 8/8 [==============================] - 0s 33ms/step - loss: 1.9661 - accuracy: 0.2500 - val_loss: 1.8820 - val_accuracy: 0.2500
# Epoch 4/150
# 8/8 [==============================] - 0s 35ms/step - loss: 1.8883 - accuracy: 0.2778 - val_loss: 1.8780 - val_accuracy: 0.2500
# Epoch 5/150
# 8/8 [==============================] - 0s 33ms/step - loss: 1.8098 - accuracy: 0.3108 - val_loss: 1.7454 - val_accuracy: 0.3194
# Epoch 6/150
# 8/8 [==============================] - 0s 32ms/step - loss: 1.7239 - accuracy: 0.3559 - val_loss: 1.7275 - val_accuracy: 0.2917
# Epoch 7/150
# 8/8 [==============================] - 0s 33ms/step - loss: 1.6879 - accuracy: 0.3802 - val_loss: 1.6717 - val_accuracy: 0.3264
# Epoch 8/150
# 8/8 [==============================] - 0s 33ms/step - loss: 1.5293 - accuracy: 0.4566 - val_loss: 1.5982 - val_accuracy: 0.4306
# Epoch 9/150
# 8/8 [==============================] - 0s 33ms/step - loss: 1.3966 - accuracy: 0.4965 - val_loss: 1.5179 - val_accuracy: 0.4167
# Epoch 10/150
# 8/8 [==============================] - 0s 33ms/step - loss: 1.3088 - accuracy: 0.5347 - val_loss: 1.5265 - val_accuracy: 0.4444
# Epoch 11/150
# 8/8 [==============================] - 0s 33ms/step - loss: 1.1852 - accuracy: 0.5608 - val_loss: 1.5511 - val_accuracy: 0.4583
# Epoch 12/150
# 8/8 [==============================] - 0s 32ms/step - loss: 1.1097 - accuracy: 0.5938 - val_loss: 1.4636 - val_accuracy: 0.4931
# Epoch 13/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.9266 - accuracy: 0.6458 - val_loss: 1.4781 - val_accuracy: 0.5486
# Epoch 14/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.8825 - accuracy: 0.6806 - val_loss: 1.4991 - val_accuracy: 0.4931
# Epoch 15/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.8053 - accuracy: 0.7205 - val_loss: 1.3698 - val_accuracy: 0.5694
# Epoch 16/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.6812 - accuracy: 0.7552 - val_loss: 1.5234 - val_accuracy: 0.5347
# Epoch 17/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.6606 - accuracy: 0.7656 - val_loss: 1.5015 - val_accuracy: 0.5556
# Epoch 18/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.5808 - accuracy: 0.8160 - val_loss: 1.6169 - val_accuracy: 0.5625
# Epoch 19/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.6104 - accuracy: 0.7951 - val_loss: 1.4328 - val_accuracy: 0.6042
# Epoch 20/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.5445 - accuracy: 0.8212 - val_loss: 1.5932 - val_accuracy: 0.5556
# Epoch 21/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4379 - accuracy: 0.8351 - val_loss: 1.6596 - val_accuracy: 0.5556
# Epoch 22/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.4586 - accuracy: 0.8420 - val_loss: 1.5413 - val_accuracy: 0.5556
# Epoch 23/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.4092 - accuracy: 0.8420 - val_loss: 1.7409 - val_accuracy: 0.5764
# Epoch 24/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3695 - accuracy: 0.8785 - val_loss: 1.7078 - val_accuracy: 0.5625
# Epoch 25/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3453 - accuracy: 0.8837 - val_loss: 1.5751 - val_accuracy: 0.5972
# Epoch 26/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2974 - accuracy: 0.8837 - val_loss: 1.7580 - val_accuracy: 0.5625
# Epoch 27/150
# 8/8 [==============================] - 0s 38ms/step - loss: 0.3055 - accuracy: 0.8941 - val_loss: 1.8879 - val_accuracy: 0.6111
# Epoch 28/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2855 - accuracy: 0.9062 - val_loss: 1.9001 - val_accuracy: 0.5694
# Epoch 29/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3068 - accuracy: 0.9062 - val_loss: 1.5881 - val_accuracy: 0.6111
# Epoch 30/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2582 - accuracy: 0.9149 - val_loss: 1.6859 - val_accuracy: 0.5833
# Epoch 31/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2320 - accuracy: 0.9253 - val_loss: 1.8765 - val_accuracy: 0.6250
# Epoch 32/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2297 - accuracy: 0.9340 - val_loss: 1.8971 - val_accuracy: 0.5764
# Epoch 33/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1983 - accuracy: 0.9358 - val_loss: 1.9388 - val_accuracy: 0.5972
# Epoch 34/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2183 - accuracy: 0.9288 - val_loss: 1.9872 - val_accuracy: 0.5486
# Epoch 35/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2150 - accuracy: 0.9288 - val_loss: 2.3240 - val_accuracy: 0.5625
# Epoch 36/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2067 - accuracy: 0.9410 - val_loss: 2.1651 - val_accuracy: 0.5903
# Epoch 37/150
# 8/8 [==============================] - 0s 35ms/step - loss: 0.1854 - accuracy: 0.9410 - val_loss: 1.9641 - val_accuracy: 0.5903
# Epoch 38/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1904 - accuracy: 0.9514 - val_loss: 2.1634 - val_accuracy: 0.5972
# Epoch 39/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1767 - accuracy: 0.9531 - val_loss: 2.1075 - val_accuracy: 0.5764
# Epoch 40/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.2223 - accuracy: 0.9306 - val_loss: 2.1054 - val_accuracy: 0.5972
# Epoch 41/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1913 - accuracy: 0.9340 - val_loss: 2.0400 - val_accuracy: 0.5833
# Epoch 42/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1715 - accuracy: 0.9410 - val_loss: 2.0530 - val_accuracy: 0.6111
# Epoch 43/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1880 - accuracy: 0.9462 - val_loss: 1.9611 - val_accuracy: 0.6319
# Epoch 44/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1346 - accuracy: 0.9653 - val_loss: 2.0097 - val_accuracy: 0.6181
# Epoch 45/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1327 - accuracy: 0.9670 - val_loss: 2.1863 - val_accuracy: 0.6181
# Epoch 46/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1414 - accuracy: 0.9566 - val_loss: 2.2122 - val_accuracy: 0.5764
# Epoch 47/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1308 - accuracy: 0.9635 - val_loss: 2.0275 - val_accuracy: 0.6250
# Epoch 48/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1439 - accuracy: 0.9653 - val_loss: 2.0895 - val_accuracy: 0.6181
# Epoch 49/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1188 - accuracy: 0.9688 - val_loss: 2.1466 - val_accuracy: 0.6250
# Epoch 50/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1412 - accuracy: 0.9531 - val_loss: 2.0410 - val_accuracy: 0.6250
# Epoch 51/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1468 - accuracy: 0.9618 - val_loss: 1.8433 - val_accuracy: 0.5903
# Epoch 52/150
# 8/8 [==============================] - 0s 39ms/step - loss: 0.1187 - accuracy: 0.9653 - val_loss: 2.1271 - val_accuracy: 0.5833
# Epoch 53/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1641 - accuracy: 0.9410 - val_loss: 1.9226 - val_accuracy: 0.6181
# Epoch 54/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1370 - accuracy: 0.9566 - val_loss: 1.9056 - val_accuracy: 0.6319
# Epoch 55/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1132 - accuracy: 0.9740 - val_loss: 1.9804 - val_accuracy: 0.6111
# Epoch 56/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0755 - accuracy: 0.9896 - val_loss: 2.3363 - val_accuracy: 0.6389
# Epoch 57/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0954 - accuracy: 0.9792 - val_loss: 2.4495 - val_accuracy: 0.6181
# Epoch 58/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0937 - accuracy: 0.9809 - val_loss: 2.4030 - val_accuracy: 0.6042
# Epoch 59/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1200 - accuracy: 0.9688 - val_loss: 2.4551 - val_accuracy: 0.5903
# Epoch 60/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1283 - accuracy: 0.9601 - val_loss: 2.0520 - val_accuracy: 0.6181
# Epoch 61/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0920 - accuracy: 0.9774 - val_loss: 2.0590 - val_accuracy: 0.6250
# Epoch 62/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0663 - accuracy: 0.9878 - val_loss: 2.1639 - val_accuracy: 0.6042
# Epoch 63/150
# 8/8 [==============================] - 0s 46ms/step - loss: 0.0872 - accuracy: 0.9757 - val_loss: 2.3385 - val_accuracy: 0.6319
# Epoch 64/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0810 - accuracy: 0.9757 - val_loss: 2.5186 - val_accuracy: 0.6181
# Epoch 65/150
# 8/8 [==============================] - 0s 36ms/step - loss: 0.0812 - accuracy: 0.9809 - val_loss: 2.4126 - val_accuracy: 0.5972
# Epoch 66/150
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0752 - accuracy: 0.9809 - val_loss: 2.4522 - val_accuracy: 0.6250
# Epoch 67/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0731 - accuracy: 0.9809 - val_loss: 2.4779 - val_accuracy: 0.6111
# Epoch 68/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0926 - accuracy: 0.9809 - val_loss: 2.5895 - val_accuracy: 0.6181
# Epoch 69/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0818 - accuracy: 0.9809 - val_loss: 2.7856 - val_accuracy: 0.5972
# Epoch 70/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0951 - accuracy: 0.9757 - val_loss: 2.5525 - val_accuracy: 0.5972
# Epoch 71/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0831 - accuracy: 0.9809 - val_loss: 2.5820 - val_accuracy: 0.5972
# Epoch 72/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0918 - accuracy: 0.9740 - val_loss: 2.5351 - val_accuracy: 0.5903
# Epoch 73/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1117 - accuracy: 0.9635 - val_loss: 2.3149 - val_accuracy: 0.5833
# Epoch 74/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0742 - accuracy: 0.9861 - val_loss: 2.2136 - val_accuracy: 0.6250
# Epoch 75/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0779 - accuracy: 0.9774 - val_loss: 2.4594 - val_accuracy: 0.6250
# Epoch 76/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0852 - accuracy: 0.9774 - val_loss: 2.2955 - val_accuracy: 0.5625
# Epoch 77/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0728 - accuracy: 0.9844 - val_loss: 2.2467 - val_accuracy: 0.5833
# Epoch 78/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0670 - accuracy: 0.9844 - val_loss: 2.4519 - val_accuracy: 0.5972
# Epoch 79/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0722 - accuracy: 0.9774 - val_loss: 2.5960 - val_accuracy: 0.6181
# Epoch 80/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0835 - accuracy: 0.9809 - val_loss: 2.4417 - val_accuracy: 0.5764
# Epoch 81/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1029 - accuracy: 0.9757 - val_loss: 2.1942 - val_accuracy: 0.6042
# Epoch 82/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1134 - accuracy: 0.9705 - val_loss: 2.1330 - val_accuracy: 0.6111
# Epoch 83/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0980 - accuracy: 0.9774 - val_loss: 2.0784 - val_accuracy: 0.6042
# Epoch 84/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0731 - accuracy: 0.9826 - val_loss: 2.2572 - val_accuracy: 0.5694
# Epoch 85/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1132 - accuracy: 0.9740 - val_loss: 2.3322 - val_accuracy: 0.6181
# Epoch 86/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0896 - accuracy: 0.9774 - val_loss: 2.3856 - val_accuracy: 0.5972
# Epoch 87/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0710 - accuracy: 0.9826 - val_loss: 2.2533 - val_accuracy: 0.6042
# Epoch 88/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0745 - accuracy: 0.9913 - val_loss: 2.2548 - val_accuracy: 0.6319
# Epoch 89/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0754 - accuracy: 0.9913 - val_loss: 2.2549 - val_accuracy: 0.6250
# Epoch 90/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0687 - accuracy: 0.9826 - val_loss: 2.4451 - val_accuracy: 0.6389
# Epoch 91/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0594 - accuracy: 0.9844 - val_loss: 2.5131 - val_accuracy: 0.6181
# Epoch 92/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0652 - accuracy: 0.9792 - val_loss: 2.7058 - val_accuracy: 0.6250
# Epoch 93/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0486 - accuracy: 0.9878 - val_loss: 2.6533 - val_accuracy: 0.5903
# Epoch 94/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0707 - accuracy: 0.9809 - val_loss: 2.7049 - val_accuracy: 0.5764
# Epoch 95/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0842 - accuracy: 0.9809 - val_loss: 2.4205 - val_accuracy: 0.6111
# Epoch 96/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0687 - accuracy: 0.9844 - val_loss: 2.3930 - val_accuracy: 0.6319
# Epoch 97/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0493 - accuracy: 0.9896 - val_loss: 2.3787 - val_accuracy: 0.6389
# Epoch 98/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0950 - accuracy: 0.9757 - val_loss: 2.6849 - val_accuracy: 0.6319
# Epoch 99/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0484 - accuracy: 0.9896 - val_loss: 3.0574 - val_accuracy: 0.5903
# Epoch 100/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0609 - accuracy: 0.9878 - val_loss: 2.8570 - val_accuracy: 0.6111
# Epoch 101/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0673 - accuracy: 0.9809 - val_loss: 2.8988 - val_accuracy: 0.5903
# Epoch 102/150
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0803 - accuracy: 0.9809 - val_loss: 2.6475 - val_accuracy: 0.5903
# Epoch 103/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0833 - accuracy: 0.9774 - val_loss: 2.3785 - val_accuracy: 0.6042
# Epoch 104/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0653 - accuracy: 0.9826 - val_loss: 2.3306 - val_accuracy: 0.6042
# Epoch 105/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0680 - accuracy: 0.9792 - val_loss: 2.3746 - val_accuracy: 0.6250
# Epoch 106/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0589 - accuracy: 0.9861 - val_loss: 2.4283 - val_accuracy: 0.6111
# Epoch 107/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0522 - accuracy: 0.9826 - val_loss: 2.4731 - val_accuracy: 0.6042
# Epoch 108/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0584 - accuracy: 0.9913 - val_loss: 2.4786 - val_accuracy: 0.6250
# Epoch 109/150
# 8/8 [==============================] - 0s 36ms/step - loss: 0.0406 - accuracy: 0.9931 - val_loss: 2.6232 - val_accuracy: 0.6250
# Epoch 110/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0468 - accuracy: 0.9878 - val_loss: 2.6969 - val_accuracy: 0.6042
# Epoch 111/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0472 - accuracy: 0.9878 - val_loss: 2.8061 - val_accuracy: 0.6111
# Epoch 112/150
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0392 - accuracy: 0.9896 - val_loss: 2.6806 - val_accuracy: 0.6181
# Epoch 113/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0340 - accuracy: 0.9948 - val_loss: 2.6188 - val_accuracy: 0.6181
# Epoch 114/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0371 - accuracy: 0.9948 - val_loss: 2.6289 - val_accuracy: 0.6458
# Epoch 115/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0316 - accuracy: 0.9948 - val_loss: 2.7513 - val_accuracy: 0.6042
# Epoch 116/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0452 - accuracy: 0.9878 - val_loss: 2.6127 - val_accuracy: 0.6042
# Epoch 117/150
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0338 - accuracy: 0.9948 - val_loss: 2.7201 - val_accuracy: 0.6250
# Epoch 118/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0500 - accuracy: 0.9844 - val_loss: 2.7183 - val_accuracy: 0.6111
# Epoch 119/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0429 - accuracy: 0.9913 - val_loss: 2.5084 - val_accuracy: 0.6042
# Epoch 120/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0401 - accuracy: 0.9896 - val_loss: 2.6329 - val_accuracy: 0.6250
# Epoch 121/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0635 - accuracy: 0.9861 - val_loss: 2.6562 - val_accuracy: 0.6319
# Epoch 122/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0543 - accuracy: 0.9861 - val_loss: 2.5948 - val_accuracy: 0.6111
# Epoch 123/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0511 - accuracy: 0.9844 - val_loss: 2.6025 - val_accuracy: 0.6250
# Epoch 124/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0496 - accuracy: 0.9878 - val_loss: 2.5189 - val_accuracy: 0.6111
# Epoch 125/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0490 - accuracy: 0.9878 - val_loss: 2.3243 - val_accuracy: 0.6181
# Epoch 126/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0373 - accuracy: 0.9878 - val_loss: 2.3829 - val_accuracy: 0.6181
# Epoch 127/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0569 - accuracy: 0.9844 - val_loss: 2.4696 - val_accuracy: 0.5972
# Epoch 128/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0553 - accuracy: 0.9896 - val_loss: 2.4687 - val_accuracy: 0.6250
# Epoch 129/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0638 - accuracy: 0.9826 - val_loss: 2.4558 - val_accuracy: 0.6181
# Epoch 130/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0674 - accuracy: 0.9826 - val_loss: 2.2320 - val_accuracy: 0.6111
# Epoch 131/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0334 - accuracy: 0.9913 - val_loss: 2.2339 - val_accuracy: 0.6458
# Epoch 132/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0473 - accuracy: 0.9861 - val_loss: 2.1545 - val_accuracy: 0.6250
# Epoch 133/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0286 - accuracy: 0.9948 - val_loss: 2.2171 - val_accuracy: 0.6181
# Epoch 134/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0353 - accuracy: 0.9931 - val_loss: 2.2599 - val_accuracy: 0.6319
# Epoch 135/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0453 - accuracy: 0.9861 - val_loss: 2.3091 - val_accuracy: 0.6319
# Epoch 136/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0261 - accuracy: 0.9983 - val_loss: 2.3205 - val_accuracy: 0.6319
# Epoch 137/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0366 - accuracy: 0.9931 - val_loss: 2.4095 - val_accuracy: 0.6181
# Epoch 138/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0410 - accuracy: 0.9913 - val_loss: 2.5118 - val_accuracy: 0.6250
# Epoch 139/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0426 - accuracy: 0.9844 - val_loss: 2.5026 - val_accuracy: 0.6181
# Epoch 140/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0390 - accuracy: 0.9931 - val_loss: 2.4430 - val_accuracy: 0.6319
# Epoch 141/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0456 - accuracy: 0.9913 - val_loss: 2.5638 - val_accuracy: 0.6250
# Epoch 142/150
# 8/8 [==============================] - 0s 40ms/step - loss: 0.0340 - accuracy: 0.9896 - val_loss: 2.3984 - val_accuracy: 0.6250
# Epoch 143/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0427 - accuracy: 0.9896 - val_loss: 2.2728 - val_accuracy: 0.6111
# Epoch 144/150
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0430 - accuracy: 0.9931 - val_loss: 2.3081 - val_accuracy: 0.6319
# Epoch 145/150
# 8/8 [==============================] - 0s 36ms/step - loss: 0.0417 - accuracy: 0.9878 - val_loss: 2.4473 - val_accuracy: 0.6250
# Epoch 146/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0454 - accuracy: 0.9913 - val_loss: 2.5393 - val_accuracy: 0.6250
# Epoch 147/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0622 - accuracy: 0.9826 - val_loss: 2.3869 - val_accuracy: 0.6319
# Epoch 148/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0364 - accuracy: 0.9931 - val_loss: 2.2550 - val_accuracy: 0.6389
# Epoch 149/150
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0402 - accuracy: 0.9913 - val_loss: 2.2319 - val_accuracy: 0.6528
# Epoch 150/150
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0281 - accuracy: 0.9948 - val_loss: 2.3123 - val_accuracy: 0.6597
# 5/5 [==============================] - 0s 5ms/step - loss: 2.3123 - accuracy: 0.6597
# Test loss: 2.3123350143432617
# Test accuracy: 0.6597222089767456

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Male Data Training and Validation Accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Male Data Training and Validation Loss')
plt.legend()
plt.show()

# %%
#Algorithm Evaluation
cm = confusion_matrix(y_test_males.argmax(axis=1), y_pred.argmax(axis=1))
print("CNN Male Emotion Classification")
df = pd.DataFrame(cm, columns=[y_males[0], y_males[4], y_males[12], y_males[20], y_males[28], y_males[36], y_males[44], y_males[52] ])
print(df)

#figure for confusion matrix
cm = confusion_matrix(y_test_males.argmax(axis=1), y_pred.argmax(axis=1))
plt.figure(figsize=(10,4))
plt.imshow(cm)
plt.title("CNN Male Emotion Classification")
plt.show()

#precision function
def precision(confmatrix):
    # precision = tp/(tp+fp)
    tp = np.diag(confmatrix)
    fp = np.sum(confmatrix, axis=0) - tp
    precision = np.mean(tp/(tp+fp))
    return precision

prec = precision(cm)
# Out:
# CNN Male Emotion Classification
#    0   1   2   3   4   5   6   7
# 0  6   0   2   2   2   1   0   0
# 1  2  17   0   3   0   0   0   0
# 2  2   1  12   0   3   0   1   0
# 3  1   4   1  10   0   1   1   0
# 4  0   0   1   0  12   0   2   0
# 5  0   0   2   0   2  12   1   2
# 6  0   1   1   0   1   0  12   1
# 7  0   1   2   3   0   2   0  14
